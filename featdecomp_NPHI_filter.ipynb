# %% [markdown]
# ### Bibliotecas

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import os
import pickle

from sklearn.preprocessing import MinMaxScaler, StandardScaler, PolynomialFeatures
from sklearn.model_selection import RepeatedKFold, RandomizedSearchCV
from sklearn.metrics import r2_score, mean_absolute_error

#Modelos
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.ensemble import StackingRegressor, VotingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import StackingRegressor
import lightgbm as lgb
import xgboost as xgb

from scipy import stats
from statsmodels.tsa.seasonal import seasonal_decompose
import itertools

from copy import deepcopy

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.simplefilter(action='ignore', category=SyntaxWarning)

# %% [markdown]
# ### Lendo Dados

# %%
df = pd.read_csv('./Data/volve_preproc.csv')
df.shape
# Out:
# (23733, 10)

# %% [markdown]
# #### Filtering Data

# %%
n=3
df2 = df[::n]
df2.shape
# Out:
# (7911, 10)

# %%
df_filt = df2.dropna()
df_filt.shape
# Out:
# (1773, 10)

# %%
df.groupby('wellName').count()
# Out:
#                 MD   CALI    DT     GR   NPHI   RHOB   PHIF     SW  RACEHM_LOG
# wellName
# 15/9-F-1 A    2099   2099  2099   2099   2099   2099   2099   2099        2099
# 15/9-F-1 B    1903   1903  1903   1903   1903   1903   1903   1903        1903
# 15/9-F-1 C    7631   7631     0   7631   7631   7631   7630   7630        7631
# 15/9-F-11 A   1402   1402  1402   1402   1402   1402   1321   1321        1402
# 15/9-F-11 B  10698  10698     0  10698  10698  10698  10698  10698       10698

# %%
df2.groupby('wellName').count()
# Out:
#                MD  CALI   DT    GR  NPHI  RHOB  PHIF    SW  RACEHM_LOG
# wellName
# 15/9-F-1 A    700   700  700   700   700   700   700   700         700
# 15/9-F-1 B    634   634  634   634   634   634   634   634         634
# 15/9-F-1 C   2544  2544    0  2544  2544  2544  2543  2543        2544
# 15/9-F-11 A   467   467  467   467   467   467   439   439         467
# 15/9-F-11 B  3566  3566    0  3566  3566  3566  3566  3566        3566

# %%
df_filt.groupby('wellName').count()
# Out:
#               MD  CALI   DT   GR  NPHI  RHOB  PHIF   SW  RACEHM_LOG
# wellName
# 15/9-F-1 A   700   700  700  700   700   700   700  700         700
# 15/9-F-1 B   634   634  634  634   634   634   634  634         634
# 15/9-F-11 A  439   439  439  439   439   439   439  439         439

# %% [markdown]
# ### Treinando modelo de ML para prever DT

# %% [markdown]
# #### Definindo a parcela de treino e de teste

# %%
training_wells = ['15/9-F-11 A', '15/9-F-1 A']
test_wells = ['15/9-F-1 B']
nodata_wells = ['15/9-F-11 B', '15/9-F-1 C'] #poços sem a informação de DT

# %%
train_df = df_filt[df_filt['wellName'].isin(training_wells)]
test_df = df_filt[df_filt['wellName'].isin(test_wells)]
nodata_df = df_filt[df_filt['wellName'].isin(nodata_wells)]

# %% [markdown]
# #### Selecionando variáveis de entrada e saída

# %%
inputs = [
    'CALI',
    'DT',
    'GR',
    # 'NPHI',
    'RHOB',
    'PHIF',
    # 'SW',
    'RACEHM_LOG'
    ]
output = ['NPHI']

# %%
X_tr = train_df[inputs]
y_tr = train_df[output]
X_te = test_df[inputs]
y_te = test_df[output]

# %%
X_tr.shape,y_tr.shape,X_te.shape,y_te.shape
# Out:
# ((1139, 6), (1139, 1), (634, 6), (634, 1))

# %%
X_tr = X_tr.values
X_te = X_te.values
y_tr = y_tr.values
y_te = y_te.values

# %% [markdown]
# #### Normalizando dados MinMax

# %%
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
X_tr = X_scaler.fit_transform(X_tr)
X_te = X_scaler.fit_transform(X_te)
y_tr = y_scaler.fit_transform(y_tr)
y_te = y_scaler.fit_transform(y_te)

# %% [markdown]
# #### Decomp

# %%
def decomp(X_tr,X_te,y_tr,y_te,period=50):
    extrapolate_trend = 5
    return seasonal_decompose(X_tr, period=period, extrapolate_trend=extrapolate_trend), seasonal_decompose(X_te, period=period, extrapolate_trend=extrapolate_trend), seasonal_decompose(y_tr, period=period, extrapolate_trend=extrapolate_trend), seasonal_decompose(y_te, period=period, extrapolate_trend=extrapolate_trend)

# %%
X_tr_dec, X_te_dec, y_tr_dec, y_te_dec = decomp(X_tr,X_te,y_tr,y_te,period=10)

# %% [markdown]
# #### Agregando X_tr, X_te

# %%
X2_tr = np.concatenate([X_tr_dec.trend,X_tr_dec.seasonal+X_tr_dec.resid], axis=1)
X2_te = np.concatenate([X_te_dec.trend,X_te_dec.seasonal+X_te_dec.resid], axis=1)

X2_tr.shape, X2_te.shape
# Out:
# ((1139, 12), (634, 12))

# %%
for i in range(X_te_dec.trend.shape[1]):
    plt.figure()
    plt.plot(X_te[:,i], label='original')
    plt.plot(X_te_dec.trend[:,i], label='trend')
    # plt.plot(X_tr_dec.seasonal[:,i], label='seasonal')
    # plt.plot(X_tr_dec.resid[:,i], label='resid')
    plt.legend()
    pass;

X_te_dec.trend.shape, X_te.shape
# Out:
# ((634, 6), (634, 6))

# %% [markdown]
# Random State

# %%
rs=48

# %% [markdown]
# #### Declarando os Modelos ML

# %%
models_ml = [
    ('Linear'   ,'LinReg'              ,      LinearRegression(copy_X=True)), #ARX Equivalet
    ('NonLinear','PolyReg'             ,      Pipeline([('Poly', PolynomialFeatures(degree=2)), ('Reg', LinearRegression(copy_X=True))])), #NARX Equivale)t
    ('NonLinear','SVM'                 ,      SVR(max_iter=-1)),
    ('NonLinear','KNN'                 ,      KNeighborsRegressor()),
    ('NonLinear','MLP'                 ,      MLPRegressor(random_state=rs)),
    ('Ensembles','DecisionTree'        ,      DecisionTreeRegressor(random_state=rs)),
    ('Ensembles','RandomForest'        ,      RandomForestRegressor(random_state=rs)),
    ('Ensembles','GradientBoosting'    ,      GradientBoostingRegressor(random_state=rs)),
    ('Ensembles','ExtraTrees'          ,      ExtraTreesRegressor(random_state=rs)),
    ('Ensembles','AdaBoostRegressor'   ,      AdaBoostRegressor(random_state=rs)),
    ('Ensembles','BaggingRegressor'    ,      BaggingRegressor(random_state=rs)),
    # ('Ensembles','LightGBM'            ,      lgb.LGBMRegressor()),
    ('Ensembles','XGBoost'             ,      xgb.XGBRegressor()),
]

# %%
for i, m in enumerate(models_ml):
    print (i, m[2])
# Out:
# 0 LinearRegression()
# 1 Pipeline(steps=[('Poly', PolynomialFeatures()), ('Reg', LinearRegression())])
# 2 SVR()
# 3 KNeighborsRegressor()
# 4 MLPRegressor(random_state=48)
# 5 DecisionTreeRegressor(random_state=48)
# 6 RandomForestRegressor(random_state=48)
# 7 GradientBoostingRegressor(random_state=48)
# 8 ExtraTreesRegressor(random_state=48)
# 9 AdaBoostRegressor(random_state=48)
# 10 BaggingRegressor(random_state=48)
# 11 XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# #### Parâmetros (RandomSearchCV)

# %%
parameters = [
    { # LinReg 0
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'positive'                     : [True, False],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    { # PolyReg NARX 1
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'Reg__positive'                : [True, False],
        #'Poly__degree'                : [2, 3, 4, 5],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    { # SVM 2
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'C'                     : stats.loguniform(1e-3, 1e3),
        'kernel'                : ['poly', 'rbf', 'sigmoid'],
        'degree'                : stats.randint(2,6),
        'gamma'                 : stats.loguniform(1e-4, 1e0),
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    { # KNN 3
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_neighbors'           : stats.randint(1,100),
        'weights'               : ['uniform', 'distance'],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    { # MLP 6
        'activation'            : ['relu', 'tanh'],
        'early_stopping'        : [True],
        'learning_rate_init'    : stats.loguniform(1e-4, 0.01),
        # 'learning_rate'         : ['adaptive', 'constant'],
        'alpha'                 : stats.loguniform(1e-5, 1e-3),
        'hidden_layer_sizes'    : []
        + [n_neurons for n_neurons in itertools.product([20, 60, 100], repeat=1)]
        + [n_neurons for n_neurons in itertools.product([20, 60, 100], repeat=2)]
        + [n_neurons for n_neurons in itertools.product([20, 60, 100], repeat=3)],
        # + [n_neurons for n_neurons in itertools.product([20, 60, 100], repeat=4)],
        # 'max_iter'              : [10000],#stats.randint(200,10000),
        # 'batch_size'            : [32],
        # 'solver'                : ['adam'], #'lbfgs'],
        'tol'                   : stats.loguniform(1e-7, 1e-1),
    },
    { # DecisionTree 7
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        #'DT__criterion'              : ['gini', 'entropy'],
        'splitter'               : ['best', 'random'],
        'max_depth'              : stats.randint(5,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    { # RandomForest 8
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    { # GradientBoosting 9
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'loss'                   : ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'learning_rate'          : stats.loguniform(1e-5, 1e1),
        'criterion'              : ['friedman_mse', 'squared_error'],
        'subsample'              : stats.uniform(),
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    { # ExtraTrees 10
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'criterion'              : ['squared_error', 'absolute_error'],
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    { # AdaBoostRegressor 11
        'n_estimators'              : stats.randint(5,100), #Numero de arvores
        'learning_rate'             : stats.loguniform(1e-3, 10),
        'loss'                      : ['linear', 'square', 'exponential'],
    },
    { # BaggingRegressor 12
        'n_estimators'              : stats.randint(5,100), #Numero de arvores
        'max_samples'               : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_features'              : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'bootstrap'                 : [True, False],      #maxima quantidade de features para embasar a decisao de divisao
    },
    # { # LightGBM 13
    #     'num_leaves'                : stats.randint(5,100), # max num folhas dos base learners
    #     'n_estimators'              : stats.randint(10,200), #Numero de arvores
    #     'learning_rate'             : stats.loguniform(1e-3, 1),
    #     # 'max_depth'                 : stats.randint(1,20), #maxima profundidade da arvore
    # },
    { # XGBoost 14
        'n_estimators'           : stats.randint(2,100), #Numero de arvores
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'learning_rate'          : stats.loguniform(1e-3, 1),
    },
]
# parameters

# %%
kfolds = 5
niters = 10
rkf = RepeatedKFold(n_splits=kfolds, n_repeats=niters, random_state=rs)
rkf
# Out:
# RepeatedKFold(n_repeats=10, n_splits=5, random_state=48)

# %% [markdown]
# #### Random Search

# %%
n_iter = 100 #Numero de iterações do rdmsearch
models=[]
for model, params in zip(models_ml, parameters):
    rdmsearch = RandomizedSearchCV(model[2], verbose=0, scoring='r2',
                                   param_distributions=params, n_iter=n_iter, n_jobs=6,
                                   cv=rkf, random_state=rs)

    models.append(
        # (model[0], model[1], rdmsearch)
        (model[1], model[2], rdmsearch, model[0])
    )

# models

# %%
def my_metrics(X_tr, X_te, y_tr, y_te, model):
    y_hat_tr = model.predict(X_tr)
    y_hat_te = model.predict(X_te)
    r2_tr  = r2_score(y_tr, y_hat_tr)
    r2_te  = r2_score(y_te, y_hat_te)
    mae_tr = mean_absolute_error(y_tr, y_hat_tr)
    mae_te = mean_absolute_error(y_te, y_hat_te)
    return r2_tr,r2_te,mae_tr,mae_te

# %% [markdown]
# #### Looping de Treinamento

# %%
res_dict = {
    'MODEL':[],
    'R2_TR':[],
    'R2_TE':[],
    'MAE_TR':[],
    'MAE_TE':[],
    'MODEL_OBJ':[],
}

for model in models:
    model_base_name, _ , model_base_instance, _ = model
    print(f'Model Base:{model_base_name}', end=' ')
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        model_base_instance.fit(X=X_tr, y=y_tr);

    r2_tr,r2_te,mae_tr,mae_te = my_metrics(X_tr, X_te, y_tr, y_te, model_base_instance)

    res_dict['MODEL'].append(model_base_name)
    res_dict['R2_TR'].append(r2_tr)
    res_dict['R2_TE'].append(r2_te)
    res_dict['MAE_TR'].append(mae_tr)
    res_dict['MAE_TE'].append(mae_te)
    res_dict['MODEL_OBJ'].append(deepcopy(model_base_instance))
    print(f'\tR2={r2_te:.2f}', end=' ')

    model_feat_name, _ , model_feat_instance, _ = model
    print(f'\tDec Feat:', end=' ')

    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        model_feat_instance.fit(X=X2_tr, y=y_tr);

    r2_tr,r2_te,mae_tr,mae_te = my_metrics(X2_tr, X2_te, y_tr, y_te, model_feat_instance)
    res_dict['MODEL'].append(f'{model_feat_name}(DEC)')
    res_dict['R2_TR'].append(r2_tr)
    res_dict['R2_TE'].append(r2_te)
    res_dict['MAE_TR'].append(mae_tr)
    res_dict['MAE_TE'].append(mae_te)
    res_dict['MODEL_OBJ'].append(deepcopy(model_feat_instance))
    print(f'\tR2={r2_te:.2f}')
# Out:
# Model Base:LinReg 	R2=0.58 	Dec Feat: 	R2=0.54
# Model Base:PolyReg 	R2=0.55 	Dec Feat: 	R2=0.49
# Model Base:SVM 	R2=0.81 	Dec Feat: 	R2=0.76
# Model Base:KNN 	R2=0.78 	Dec Feat: 	R2=0.71
# Model Base:MLP 	R2=0.82 	Dec Feat: 	R2=0.84
# Model Base:DecisionTree 	R2=0.70 	Dec Feat: 	R2=0.61
# Model Base:RandomForest 	R2=0.76 	Dec Feat: 	R2=0.77
# Model Base:GradientBoosting 	R2=0.73 	Dec Feat: 	R2=0.73
# Model Base:ExtraTrees 	R2=0.78 	Dec Feat: 	R2=0.68
# Model Base:AdaBoostRegressor 	R2=0.74 	Dec Feat: 	R2=0.69
# Model Base:BaggingRegressor 	R2=0.76 	Dec Feat: 	R2=0.77
# Model Base:XGBoost 	R2=0.73 	Dec Feat: 	R2=0.74

# %%
df_results = pd.DataFrame(res_dict)
df_results = df_results.sort_values('R2_TE', ascending=False).reset_index(drop=True)
df_results['IN'] = '.'.join(inputs)
df_results['OUT'] = output[0]
df_results
# Out:
#                      MODEL     R2_TR     R2_TE    MAE_TR    MAE_TE  \
# 0                 MLP(DEC)  0.875294  0.838061  0.037096  0.041174
# 1                      MLP  0.843075  0.820392  0.040720  0.042883
# 2                      SVM  0.805760  0.811180  0.047795  0.041934
# 3               ExtraTrees  0.893855  0.781812  0.031719  0.046361
# 4                      KNN  1.000000  0.776822  0.000000  0.049042
# 5        RandomForest(DEC)  0.962070  0.772960  0.020496  0.050775
# 6    BaggingRegressor(DEC)  0.978148  0.767821  0.014647  0.050039
# 7             RandomForest  0.951188  0.763105  0.023517  0.048109
# 8                 SVM(DEC)  0.831163  0.762165  0.045501  0.047523
# 9         BaggingRegressor  0.973894  0.758333  0.016091  0.047862
# 10       AdaBoostRegressor  0.811053  0.737848  0.050787  0.050682
# 11            XGBoost(DEC)  0.999157  0.737099  0.002880  0.053329
# 12   GradientBoosting(DEC)  0.984502  0.734648  0.012499  0.052607
# 13                 XGBoost  0.981021  0.730362  0.014053  0.051216
# 14        GradientBoosting  0.972400  0.725867  0.016983  0.050526
# 15                KNN(DEC)  1.000000  0.706657  0.000000  0.055805
# 16            DecisionTree  0.873146  0.696838  0.036997  0.056640
# 17  AdaBoostRegressor(DEC)  0.822840  0.693761  0.049936  0.056104
# 18         ExtraTrees(DEC)  0.940820  0.681273  0.026101  0.056559
# 19       DecisionTree(DEC)  0.868653  0.612557  0.038217  0.062046
# 20                  LinReg  0.757447  0.581893  0.051299  0.066363
# 21                 PolyReg  0.773259  0.551464  0.050320  0.068107
# 22             LinReg(DEC)  0.784624  0.536723  0.048787  0.071805
# 23            PolyReg(DEC)  0.809503  0.493420  0.046271  0.073794
#
#                                             MODEL_OBJ  \
# 0   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 1   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 2   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 3   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 4   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 5   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 6   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 7   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 8   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 9   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 10  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 11  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 12  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 13  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 14  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 15  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 16  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 17  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 18  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 19  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 20  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 21  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 22  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 23  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
#
#                                  IN   OUT
# 0   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 1   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 2   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 3   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 4   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 5   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 6   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 7   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 8   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 9   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 10  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 11  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 12  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 13  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 14  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 15  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 16  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 17  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 18  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 19  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 20  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 21  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 22  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 23  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI

# %%
lim = (0.5, 1)
fsize = (6, 6)

plt.figure(figsize=fsize)
sns.scatterplot(data=df_results.iloc[:10,:], y='R2_TE', x='R2_TR', hue='MODEL', s=100, palette='tab10')
plt.plot([0,1],[0,1], 'r--')
plt.xlim(lim)
plt.ylim(lim)
# Out:
# (0.5, 1.0)

# %%
best_model_index = 0
best_base_model_index = 1

best_model = df_results.loc[best_model_index,:]
best_base_model = df_results.loc[best_base_model_index,:]

y_hat = best_model['MODEL_OBJ'].predict(X2_te)
y_hat_base = best_base_model['MODEL_OBJ'].predict(X_te)

# %%
plt.figure(figsize=(6,9))
plt.plot(y_te,test_df['MD'], 'o', color='#999999', label='$y$ - observed');
plt.plot(y_hat_base,test_df['MD'], 'r', lw=2, label='$\hat{y}$ ('+f'$R^2$={r2_score(y_te, y_hat_base):.2f})')
plt.plot(y_hat,test_df['MD'], 'k', lw=2, label='$\hat{y}$ ('+f'$R^2$={r2_score(y_te, y_hat):.2f})')
plt.gca().invert_yaxis()
# plt.title(f'{best_model['MODEL']} prediction for {output[0]}, $R^2$:{r2_score(y_te, y_hat):.3f}')
plt.xlabel(f'Normalized {output[0]}')
plt.legend()
plt.ylabel('Depth[m]')
plt.grid()
pass;

# %%
fig = plt.figure(figsize=(5,5))
# fig = plt.figure(figsize=(12,12))
lim =(0,1)

sns.scatterplot(x=y_te.ravel(), y=y_hat.ravel(), s=50, color='.3')
# sns.kdeplot(x=y_te.ravel(), y=y_hat.ravel(), levels=10, linewidths=1, thresh=0.01, color='grey')

plt.plot(lim, lim, 'r--', label='$\hat{y}=y$')
plt.xlim(lim)
plt.ylim(lim)

plt.xlabel('$y$ - observed')
plt.ylabel('$\hat{y}$ - predictions')

plt.legend(loc='upper left')

plt.title(f"Observed x Predictions \n {df_results.loc[0,'MODEL']}: R²:{df_results.loc[0,'R2_TE']:.3f}")

# p = os.path.join(os.getcwd(), 'outputs', 'images_ensembles', '7_crossplot_y_yhat.eps')
# fig.savefig(p, format='eps')
pass;

# %%
prefix = 'FEATDEC_NPHI_FILT'
binary = os.path.join(os.getcwd(), 'Outputs', f'{prefix}.pkl')
print(binary)

with open(binary, 'wb') as bin_file:
    pickle.dump(df_results, bin_file)
# Out:
# c:\Users\bewm\2_Projetos\Mestrado\SYSID_well_logs\Outputs\FEATDEC_NPHI_FILT.pkl

# %% [markdown]
# #### Estudos dos parametros e tempos de treinamento

# %%
for i,m in enumerate(df_results['MODEL_OBJ']):
    if type(m)==tuple:
        tt = np.mean(m[0].cv_results_['mean_fit_time'])+np.mean(m[1].cv_results_['mean_fit_time'])
        name = m[0].best_estimator_.__class__.__name__ +'/'+ m[1].best_estimator_.__class__.__name__
        dfp1 = m[0].best_estimator_.get_params()
        dfp2 = m[1].best_estimator_.get_params()
        print (f"{name}:", f"{tt*1000:.0f} ms\n", dfp1,'\n', dfp2)
    else:
        tt = np.mean(m.cv_results_['mean_fit_time'])
        name = m.best_estimator_.__class__.__name__
        dfp1 = m.best_estimator_.get_params()
        print (f"{name}:", f"{tt*1000:.0f} ms\n", dfp1)
# Out:
# SVR/MLPRegressor: 362 ms
#  {'C': 19.394438161733895, 'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'epsilon': 0.1, 'gamma': 0.6795283158782065, 'kernel': 'poly', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'activation': 'tanh', 'alpha': 4.3831195400168764e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 20, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0005972053480787244, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 0.016207465939656832, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# SVR/Pipeline: 22 ms
#  {'C': 19.394438161733895, 'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'epsilon': 0.1, 'gamma': 0.6795283158782065, 'kernel': 'poly', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression(positive=True))], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(positive=True), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': True}
# SVR/LinearRegression: 20 ms
#  {'C': 19.394438161733895, 'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'epsilon': 0.1, 'gamma': 0.6795283158782065, 'kernel': 'poly', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# SVR/XGBRegressor: 336 ms
#  {'C': 19.394438161733895, 'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'epsilon': 0.1, 'gamma': 0.6795283158782065, 'kernel': 'poly', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.15856520978973462, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 3, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 20, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# SVR/ExtraTreesRegressor: 127 ms
#  {'C': 19.394438161733895, 'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'epsilon': 0.1, 'gamma': 0.6795283158782065, 'kernel': 'poly', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 13, 'max_features': 0.81005717500482, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 85, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# SVR/GradientBoostingRegressor: 278 ms
#  {'C': 19.394438161733895, 'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'epsilon': 0.1, 'gamma': 0.6795283158782065, 'kernel': 'poly', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.0749766036634768, 'loss': 'squared_error', 'max_depth': 4, 'max_features': 0.3493465286719911, 'max_leaf_nodes': 121, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 17, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 38, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.4720854566650611, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# SVR/BaggingRegressor: 205 ms
#  {'C': 19.394438161733895, 'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'epsilon': 0.1, 'gamma': 0.6795283158782065, 'kernel': 'poly', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'bootstrap': False, 'bootstrap_features': False, 'estimator': None, 'max_features': 0.8715844672766424, 'max_samples': 0.3208916576246922, 'n_estimators': 92, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# AdaBoostRegressor/SVR: 161 ms
#  {'estimator': None, 'learning_rate': 0.1559263904157457, 'loss': 'linear', 'n_estimators': 96, 'random_state': 48}
#  {'C': 1.2939069324365244, 'cache_size': 200, 'coef0': 0.0, 'degree': 4, 'epsilon': 0.1, 'gamma': 0.390557588154201, 'kernel': 'sigmoid', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# SVR/RandomForestRegressor: 137 ms
#  {'C': 19.394438161733895, 'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'epsilon': 0.1, 'gamma': 0.6795283158782065, 'kernel': 'poly', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 9, 'max_features': 0.536181930073022, 'max_leaf_nodes': 42, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 15, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 76, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# AdaBoostRegressor/Pipeline: 158 ms
#  {'estimator': None, 'learning_rate': 0.1559263904157457, 'loss': 'linear', 'n_estimators': 96, 'random_state': 48}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression(positive=True))], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(positive=True), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': True}
# SVR/AdaBoostRegressor: 173 ms
#  {'C': 19.394438161733895, 'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'epsilon': 0.1, 'gamma': 0.6795283158782065, 'kernel': 'poly', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'estimator': None, 'learning_rate': 0.059058058123450156, 'loss': 'exponential', 'n_estimators': 65, 'random_state': 48}
# AdaBoostRegressor/ExtraTreesRegressor: 264 ms
#  {'estimator': None, 'learning_rate': 0.1559263904157457, 'loss': 'linear', 'n_estimators': 96, 'random_state': 48}
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 13, 'max_features': 0.81005717500482, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 85, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# AdaBoostRegressor/MLPRegressor: 501 ms
#  {'estimator': None, 'learning_rate': 0.1559263904157457, 'loss': 'linear', 'n_estimators': 96, 'random_state': 48}
#  {'activation': 'tanh', 'alpha': 4.3831195400168764e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 20, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0005972053480787244, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 0.016207465939656832, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# AdaBoostRegressor/XGBRegressor: 466 ms
#  {'estimator': None, 'learning_rate': 0.1559263904157457, 'loss': 'linear', 'n_estimators': 96, 'random_state': 48}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.15856520978973462, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 3, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 20, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# AdaBoostRegressor/GradientBoostingRegressor: 412 ms
#  {'estimator': None, 'learning_rate': 0.1559263904157457, 'loss': 'linear', 'n_estimators': 96, 'random_state': 48}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.0749766036634768, 'loss': 'squared_error', 'max_depth': 4, 'max_features': 0.3493465286719911, 'max_leaf_nodes': 121, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 17, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 38, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.4720854566650611, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# AdaBoostRegressor/LinearRegression: 156 ms
#  {'estimator': None, 'learning_rate': 0.1559263904157457, 'loss': 'linear', 'n_estimators': 96, 'random_state': 48}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# AdaBoostRegressor/RandomForestRegressor: 275 ms
#  {'estimator': None, 'learning_rate': 0.1559263904157457, 'loss': 'linear', 'n_estimators': 96, 'random_state': 48}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 9, 'max_features': 0.536181930073022, 'max_leaf_nodes': 42, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 15, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 76, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# AdaBoostRegressor/BaggingRegressor: 345 ms
#  {'estimator': None, 'learning_rate': 0.1559263904157457, 'loss': 'linear', 'n_estimators': 96, 'random_state': 48}
#  {'bootstrap': False, 'bootstrap_features': False, 'estimator': None, 'max_features': 0.8715844672766424, 'max_samples': 0.3208916576246922, 'n_estimators': 92, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# SVR/KNeighborsRegressor: 20 ms
#  {'C': 19.394438161733895, 'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'epsilon': 0.1, 'gamma': 0.6795283158782065, 'kernel': 'poly', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# AdaBoostRegressor/KNeighborsRegressor: 156 ms
#  {'estimator': None, 'learning_rate': 0.1559263904157457, 'loss': 'linear', 'n_estimators': 96, 'random_state': 48}
#  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# LinearRegression/SVR: 9 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'C': 1.2939069324365244, 'cache_size': 200, 'coef0': 0.0, 'degree': 4, 'epsilon': 0.1, 'gamma': 0.390557588154201, 'kernel': 'sigmoid', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# AdaBoostRegressor: 150 ms
#  {'estimator': None, 'learning_rate': 0.207482446656461, 'loss': 'exponential', 'n_estimators': 85, 'random_state': 48}
# LinearRegression/MLPRegressor: 355 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'activation': 'tanh', 'alpha': 4.3831195400168764e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 20, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0005972053480787244, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 0.016207465939656832, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# AdaBoostRegressor/DecisionTreeRegressor: 157 ms
#  {'estimator': None, 'learning_rate': 0.1559263904157457, 'loss': 'linear', 'n_estimators': 96, 'random_state': 48}
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 0.8716520025777498, 'max_leaf_nodes': 26, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 6, 'min_samples_split': 7, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
# SVR/DecisionTreeRegressor: 21 ms
#  {'C': 19.394438161733895, 'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'epsilon': 0.1, 'gamma': 0.6795283158782065, 'kernel': 'poly', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 0.8716520025777498, 'max_leaf_nodes': 26, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 6, 'min_samples_split': 7, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
# XGBRegressor: 251 ms
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.13149387720039063, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 40, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# LinearRegression/Pipeline: 4 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression(positive=True))], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(positive=True), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': True}
# LinearRegression/ExtraTreesRegressor: 112 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 13, 'max_features': 0.81005717500482, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 85, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# LinearRegression/XGBRegressor: 322 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.15856520978973462, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 3, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 20, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# SVR: 23 ms
#  {'C': 0.9681853493885477, 'cache_size': 200, 'coef0': 0.0, 'degree': 5, 'epsilon': 0.1, 'gamma': 0.7702015133044666, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# LinearRegression/GradientBoostingRegressor: 262 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.0749766036634768, 'loss': 'squared_error', 'max_depth': 4, 'max_features': 0.3493465286719911, 'max_leaf_nodes': 121, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 17, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 38, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.4720854566650611, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# LinearRegression/RandomForestRegressor: 120 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 9, 'max_features': 0.536181930073022, 'max_leaf_nodes': 42, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 15, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 76, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# LinearRegression/AdaBoostRegressor: 156 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'estimator': None, 'learning_rate': 0.059058058123450156, 'loss': 'exponential', 'n_estimators': 65, 'random_state': 48}
# LinearRegression/BaggingRegressor: 193 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'bootstrap': False, 'bootstrap_features': False, 'estimator': None, 'max_features': 0.8715844672766424, 'max_samples': 0.3208916576246922, 'n_estimators': 92, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# RandomForestRegressor/SVR: 121 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'C': 1.2939069324365244, 'cache_size': 200, 'coef0': 0.0, 'degree': 4, 'epsilon': 0.1, 'gamma': 0.390557588154201, 'kernel': 'sigmoid', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# RandomForestRegressor/MLPRegressor: 471 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'activation': 'tanh', 'alpha': 4.3831195400168764e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 20, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0005972053480787244, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 0.016207465939656832, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# LinearRegression: 1 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# LinearRegression/KNeighborsRegressor: 2 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# RandomForestRegressor/Pipeline: 116 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression(positive=True))], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(positive=True), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': True}
# RandomForestRegressor/LinearRegression: 112 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# DecisionTreeRegressor: 2 ms
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 6, 'max_features': 0.9735377095988006, 'max_leaf_nodes': 65, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 11, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
# RandomForestRegressor/XGBRegressor: 428 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.15856520978973462, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 3, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 20, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# RandomForestRegressor/ExtraTreesRegressor: 219 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 13, 'max_features': 0.81005717500482, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 85, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# RandomForestRegressor/GradientBoostingRegressor: 374 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.0749766036634768, 'loss': 'squared_error', 'max_depth': 4, 'max_features': 0.3493465286719911, 'max_leaf_nodes': 121, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 17, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 38, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.4720854566650611, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# ExtraTreesRegressor/SVR: 135 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.6588953624220839, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'C': 1.2939069324365244, 'cache_size': 200, 'coef0': 0.0, 'degree': 4, 'epsilon': 0.1, 'gamma': 0.390557588154201, 'kernel': 'sigmoid', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# RandomForestRegressor/BaggingRegressor: 299 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'bootstrap': False, 'bootstrap_features': False, 'estimator': None, 'max_features': 0.8715844672766424, 'max_samples': 0.3208916576246922, 'n_estimators': 92, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# RandomForestRegressor/AdaBoostRegressor: 265 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'estimator': None, 'learning_rate': 0.059058058123450156, 'loss': 'exponential', 'n_estimators': 65, 'random_state': 48}
# RandomForestRegressor: 108 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 14, 'max_features': 0.6148282394928895, 'max_leaf_nodes': 96, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 3, 'min_samples_split': 5, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 76, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# LinearRegression/DecisionTreeRegressor: 3 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 0.8716520025777498, 'max_leaf_nodes': 26, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 6, 'min_samples_split': 7, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
# ExtraTreesRegressor/MLPRegressor: 475 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.6588953624220839, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'activation': 'tanh', 'alpha': 4.3831195400168764e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 20, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0005972053480787244, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 0.016207465939656832, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# ExtraTreesRegressor: 132 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 13, 'max_features': 0.81005717500482, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 85, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# ExtraTreesRegressor/LinearRegression: 131 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.6588953624220839, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# ExtraTreesRegressor/XGBRegressor: 446 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.6588953624220839, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.15856520978973462, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 3, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 20, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# ExtraTreesRegressor/Pipeline: 129 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.6588953624220839, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression(positive=True))], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(positive=True), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': True}
# ExtraTreesRegressor/GradientBoostingRegressor: 388 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.6588953624220839, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.0749766036634768, 'loss': 'squared_error', 'max_depth': 4, 'max_features': 0.3493465286719911, 'max_leaf_nodes': 121, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 17, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 38, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.4720854566650611, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# ExtraTreesRegressor/RandomForestRegressor: 247 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.6588953624220839, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 9, 'max_features': 0.536181930073022, 'max_leaf_nodes': 42, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 15, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 76, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# ExtraTreesRegressor/AdaBoostRegressor: 278 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.6588953624220839, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'estimator': None, 'learning_rate': 0.059058058123450156, 'loss': 'exponential', 'n_estimators': 65, 'random_state': 48}
# ExtraTreesRegressor/BaggingRegressor: 318 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.6588953624220839, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'bootstrap': False, 'bootstrap_features': False, 'estimator': None, 'max_features': 0.8715844672766424, 'max_samples': 0.3208916576246922, 'n_estimators': 92, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# RandomForestRegressor/KNeighborsRegressor: 117 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# BaggingRegressor: 173 ms
#  {'bootstrap': False, 'bootstrap_features': False, 'estimator': None, 'max_features': 0.8715844672766424, 'max_samples': 0.3208916576246922, 'n_estimators': 92, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# RandomForestRegressor/DecisionTreeRegressor: 113 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 0.8716520025777498, 'max_leaf_nodes': 26, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 6, 'min_samples_split': 7, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
# Pipeline: 3 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
# ExtraTreesRegressor/KNeighborsRegressor: 129 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.6588953624220839, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# ExtraTreesRegressor/DecisionTreeRegressor: 131 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.6588953624220839, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 0.8716520025777498, 'max_leaf_nodes': 26, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 6, 'min_samples_split': 7, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
# Pipeline/SVR: 10 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'C': 1.2939069324365244, 'cache_size': 200, 'coef0': 0.0, 'degree': 4, 'epsilon': 0.1, 'gamma': 0.390557588154201, 'kernel': 'sigmoid', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# BaggingRegressor/SVR: 184 ms
#  {'bootstrap': False, 'bootstrap_features': False, 'estimator': None, 'max_features': 0.994482794551525, 'max_samples': 0.7241088978456394, 'n_estimators': 78, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'C': 1.2939069324365244, 'cache_size': 200, 'coef0': 0.0, 'degree': 4, 'epsilon': 0.1, 'gamma': 0.390557588154201, 'kernel': 'sigmoid', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# GradientBoostingRegressor/SVR: 224 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
#  {'C': 1.2939069324365244, 'cache_size': 200, 'coef0': 0.0, 'degree': 4, 'epsilon': 0.1, 'gamma': 0.390557588154201, 'kernel': 'sigmoid', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# GradientBoostingRegressor: 231 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# Pipeline/MLPRegressor: 351 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'activation': 'tanh', 'alpha': 4.3831195400168764e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 20, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0005972053480787244, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 0.016207465939656832, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# BaggingRegressor/MLPRegressor: 521 ms
#  {'bootstrap': False, 'bootstrap_features': False, 'estimator': None, 'max_features': 0.994482794551525, 'max_samples': 0.7241088978456394, 'n_estimators': 78, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'activation': 'tanh', 'alpha': 4.3831195400168764e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 20, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0005972053480787244, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 0.016207465939656832, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# GradientBoostingRegressor/MLPRegressor: 561 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
#  {'activation': 'tanh', 'alpha': 4.3831195400168764e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 20, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0005972053480787244, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 0.016207465939656832, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# Pipeline/LinearRegression: 3 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# KNeighborsRegressor: 1 ms
#  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# Pipeline/ExtraTreesRegressor: 112 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 13, 'max_features': 0.81005717500482, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 85, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# Pipeline/XGBRegressor: 321 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.15856520978973462, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 3, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 20, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# Pipeline/GradientBoostingRegressor: 263 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.0749766036634768, 'loss': 'squared_error', 'max_depth': 4, 'max_features': 0.3493465286719911, 'max_leaf_nodes': 121, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 17, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 38, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.4720854566650611, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# BaggingRegressor/LinearRegression: 177 ms
# ...
#  {'activation': 'tanh', 'alpha': 4.3831195400168764e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 20, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0005972053480787244, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 0.016207465939656832, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# DecisionTreeRegressor/ExtraTreesRegressor: 108 ms
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 17, 'max_features': 0.8864802538069065, 'max_leaf_nodes': 142, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 8, 'min_samples_split': 9, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 13, 'max_features': 0.81005717500482, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 85, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# DecisionTreeRegressor/BaggingRegressor: 188 ms
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 17, 'max_features': 0.8864802538069065, 'max_leaf_nodes': 142, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 8, 'min_samples_split': 9, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
#  {'bootstrap': False, 'bootstrap_features': False, 'estimator': None, 'max_features': 0.8715844672766424, 'max_samples': 0.3208916576246922, 'n_estimators': 92, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# DecisionTreeRegressor/XGBRegressor: 320 ms
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 17, 'max_features': 0.8864802538069065, 'max_leaf_nodes': 142, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 8, 'min_samples_split': 9, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.15856520978973462, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 3, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 20, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# DecisionTreeRegressor/RandomForestRegressor: 118 ms
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 17, 'max_features': 0.8864802538069065, 'max_leaf_nodes': 142, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 8, 'min_samples_split': 9, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 9, 'max_features': 0.536181930073022, 'max_leaf_nodes': 42, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 15, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 76, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# DecisionTreeRegressor/GradientBoostingRegressor: 256 ms
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 17, 'max_features': 0.8864802538069065, 'max_leaf_nodes': 142, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 8, 'min_samples_split': 9, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.0749766036634768, 'loss': 'squared_error', 'max_depth': 4, 'max_features': 0.3493465286719911, 'max_leaf_nodes': 121, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 17, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 38, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.4720854566650611, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# DecisionTreeRegressor/LinearRegression: 3 ms
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 17, 'max_features': 0.8864802538069065, 'max_leaf_nodes': 142, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 8, 'min_samples_split': 9, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# DecisionTreeRegressor/Pipeline: 4 ms
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 17, 'max_features': 0.8864802538069065, 'max_leaf_nodes': 142, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 8, 'min_samples_split': 9, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression(positive=True))], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(positive=True), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': True}
# DecisionTreeRegressor/AdaBoostRegressor: 151 ms
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 17, 'max_features': 0.8864802538069065, 'max_leaf_nodes': 142, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 8, 'min_samples_split': 9, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
#  {'estimator': None, 'learning_rate': 0.059058058123450156, 'loss': 'exponential', 'n_estimators': 65, 'random_state': 48}
# DecisionTreeRegressor/KNeighborsRegressor: 3 ms
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 17, 'max_features': 0.8864802538069065, 'max_leaf_nodes': 142, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 8, 'min_samples_split': 9, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
#  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# KNeighborsRegressor/KNeighborsRegressor: 3 ms
#  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
#  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# SVR/SVR: 15 ms
#  {'C': 1.2939069324365244, 'cache_size': 200, 'coef0': 0.0, 'degree': 4, 'epsilon': 0.1, 'gamma': 0.390557588154201, 'kernel': 'sigmoid', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'C': 1.2939069324365244, 'cache_size': 200, 'coef0': 0.0, 'degree': 4, 'epsilon': 0.1, 'gamma': 0.390557588154201, 'kernel': 'sigmoid', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# XGBRegressor/XGBRegressor: 639 ms
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.15856520978973462, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 3, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 20, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.15856520978973462, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 3, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 20, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# AdaBoostRegressor/AdaBoostRegressor: 307 ms
#  {'estimator': None, 'learning_rate': 0.059058058123450156, 'loss': 'exponential', 'n_estimators': 65, 'random_state': 48}
#  {'estimator': None, 'learning_rate': 0.059058058123450156, 'loss': 'exponential', 'n_estimators': 65, 'random_state': 48}
# ExtraTreesRegressor/ExtraTreesRegressor: 214 ms
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 13, 'max_features': 0.81005717500482, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 85, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 13, 'max_features': 0.81005717500482, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 85, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# GradientBoostingRegressor/GradientBoostingRegressor: 508 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.0749766036634768, 'loss': 'squared_error', 'max_depth': 4, 'max_features': 0.3493465286719911, 'max_leaf_nodes': 121, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 17, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 38, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.4720854566650611, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.0749766036634768, 'loss': 'squared_error', 'max_depth': 4, 'max_features': 0.3493465286719911, 'max_leaf_nodes': 121, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 17, 'min_samples_split': 16, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 38, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.4720854566650611, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# RandomForestRegressor/RandomForestRegressor: 236 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 9, 'max_features': 0.536181930073022, 'max_leaf_nodes': 42, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 15, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 76, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 9, 'max_features': 0.536181930073022, 'max_leaf_nodes': 42, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 15, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 76, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# MLPRegressor/MLPRegressor: 694 ms
#  {'activation': 'tanh', 'alpha': 4.3831195400168764e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 20, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0005972053480787244, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 0.016207465939656832, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#  {'activation': 'tanh', 'alpha': 4.3831195400168764e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 20, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0005972053480787244, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 0.016207465939656832, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# LinearRegression/LinearRegression: 2 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# BaggingRegressor/BaggingRegressor: 376 ms
#  {'bootstrap': False, 'bootstrap_features': False, 'estimator': None, 'max_features': 0.8715844672766424, 'max_samples': 0.3208916576246922, 'n_estimators': 92, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'bootstrap': False, 'bootstrap_features': False, 'estimator': None, 'max_features': 0.8715844672766424, 'max_samples': 0.3208916576246922, 'n_estimators': 92, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# DecisionTreeRegressor/DecisionTreeRegressor: 4 ms
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 0.8716520025777498, 'max_leaf_nodes': 26, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 6, 'min_samples_split': 7, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
#  {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 5, 'max_features': 0.8716520025777498, 'max_leaf_nodes': 26, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 6, 'min_samples_split': 7, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 48, 'splitter': 'best'}
# Pipeline/Pipeline: 5 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression(positive=True))], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(positive=True), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': True}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression(positive=True))], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(positive=True), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': True}
