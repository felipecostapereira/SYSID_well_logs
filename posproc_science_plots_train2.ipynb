# %% [markdown]
# ### Bibliotecas

# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from statsmodels.tsa.seasonal import seasonal_decompose

import scienceplots
plt.style.use('science')

# %% [markdown]
# ### Lendo Dados

# %%
vars = [
    'DT',
    'NPHI',
    'RES',
    'RHOB',
]
paths = []
for v in vars:
    paths.append(os.path.join(os.getcwd(),'Outputs', f'ENS_{v}_FILT.pkl'))
    paths.append(os.path.join(os.getcwd(),'Outputs', f'FEATDEC_{v}_FILT.pkl'))
paths
# Out:
# ['c:\\Users\\bewm\\OneDrive - PETROBRAS\\Documents\\2_Projetos\\Mestrado\\SYSID_well_logs\\Outputs\\ENS_DT_FILT.pkl',
#  'c:\\Users\\bewm\\OneDrive - PETROBRAS\\Documents\\2_Projetos\\Mestrado\\SYSID_well_logs\\Outputs\\FEATDEC_DT_FILT.pkl',
#  'c:\\Users\\bewm\\OneDrive - PETROBRAS\\Documents\\2_Projetos\\Mestrado\\SYSID_well_logs\\Outputs\\ENS_NPHI_FILT.pkl',
#  'c:\\Users\\bewm\\OneDrive - PETROBRAS\\Documents\\2_Projetos\\Mestrado\\SYSID_well_logs\\Outputs\\FEATDEC_NPHI_FILT.pkl',
#  'c:\\Users\\bewm\\OneDrive - PETROBRAS\\Documents\\2_Projetos\\Mestrado\\SYSID_well_logs\\Outputs\\ENS_RES_FILT.pkl',
#  'c:\\Users\\bewm\\OneDrive - PETROBRAS\\Documents\\2_Projetos\\Mestrado\\SYSID_well_logs\\Outputs\\FEATDEC_RES_FILT.pkl',
#  'c:\\Users\\bewm\\OneDrive - PETROBRAS\\Documents\\2_Projetos\\Mestrado\\SYSID_well_logs\\Outputs\\ENS_RHOB_FILT.pkl',
#  'c:\\Users\\bewm\\OneDrive - PETROBRAS\\Documents\\2_Projetos\\Mestrado\\SYSID_well_logs\\Outputs\\FEATDEC_RHOB_FILT.pkl']

# %%
dfs=pd.DataFrame()
for p in paths:
    dfs = pd.concat([dfs,pd.read_pickle(p)], axis=0)
dfs
# Out:
#                      MODEL     R2_TR     R2_TE    MAE_TR    MAE_TE  \
# 0                  SVM.SVM  0.843406  0.852442  0.065727  0.060369
# 1                  SVM.MLP  0.844872  0.847915  0.065208  0.061507
# 2              SVM.PolyReg  0.843652  0.846300  0.065080  0.061619
# 3               SVM.LinReg  0.846253  0.844257  0.064814  0.062311
# 4              SVM.XGBoost  0.860108  0.843387  0.061999  0.062693
# ..                     ...       ...       ...       ...       ...
# 19       AdaBoostRegressor  0.889069  0.643324  0.051402  0.071803
# 20            XGBoost(DEC)  0.984780  0.640055  0.016553  0.070281
# 21  AdaBoostRegressor(DEC)  0.870081  0.583292  0.055865  0.080798
# 22            DecisionTree  0.960471  0.554287  0.026371  0.065496
# 23       DecisionTree(DEC)  0.965570  0.400563  0.024894  0.086555
#
#                                             MODEL_OBJ  \
# 0   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 1   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 2   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 3   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 4   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# ..                                                ...
# 19  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 20  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 21  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 22  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 23  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
#
#                               IN   OUT   RMSE_TR   RMSE_TE
# 0   GR.NPHI.RHOB.PHIF.RACEHM_LOG    DT  0.085583  0.070805
# 1   GR.NPHI.RHOB.PHIF.RACEHM_LOG    DT  0.085181  0.071883
# 2   GR.NPHI.RHOB.PHIF.RACEHM_LOG    DT  0.085515  0.072264
# 3   GR.NPHI.RHOB.PHIF.RACEHM_LOG    DT  0.084801  0.072742
# 4   GR.NPHI.RHOB.PHIF.RACEHM_LOG    DT  0.080890  0.072945
# ..                           ...   ...       ...       ...
# 19      DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.059845  0.088468
# 20      DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.022167  0.088872
# 21      DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.064764  0.095623
# 22      DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.035724  0.098895
# 23      DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.033340  0.114688
#
# [384 rows x 10 columns]

# %%
df_results = dfs.sort_values('R2_TE', ascending=False).reset_index(drop=True)

# %%
def model_class(row):
    if 'DEC' in row['MODEL']:
        model_class = 'FEAT_DEC'
    elif '.' in row['MODEL']:
        model_class = 'ENSEMBLE'
    else:
        model_class = 'BASE'
    return model_class
def estim(row):
    if 'DEC' in row['MODEL']:
        estim = row['MODEL'].split('(')[0]
    elif '.' in row['MODEL']:
        estim = row['MODEL'].split('.')[0]
    else:
        estim = row['MODEL']
    return estim
# def season_model(row):
#     estim = None
#     if '.' in row['MODEL']:
#         estim = row['MODEL'].split('.')[1]
#     return estim

# %%
df_results['CASE'] = df_results.apply(model_class, axis=1)
df_results['ESTIMATOR'] = df_results.apply(estim, axis=1)
# df_results['SEASONAL'] = df_results.apply(season_model, axis=1)
df_results['ESTIMATOR'].value_counts()
# Out:
# ESTIMATOR
# PolyReg              44
# SVM                  44
# MLP                  44
# AdaBoostRegressor    44
# LinReg               44
# XGBoost              44
# RandomForest         44
# GradientBoosting     44
# ExtraTrees            8
# KNN                   8
# DecisionTree          8
# BaggingRegressor      8
# Name: count, dtype: int64

# %%
df_results['CASE'].unique()
# Out:
# array(['FEAT_DEC', 'ENSEMBLE', 'BASE'], dtype=object)

# %%
remove_estimators = [
    # 'PolyReg',
    # 'MLP',
    # 'SVM',
    # 'AdaBoostRegressor',
    'ExtraTrees',
    # 'LinReg',
    # 'XGBoost',
    # 'RandomForest',
    'KNN',
    'DecisionTree',
    # 'GradientBoosting',
    'BaggingRegressor',
]

df_results = df_results[~df_results['ESTIMATOR'].isin(remove_estimators)]
# df_results = df_results[~df_results['SEASONAL'].isin(remove_estimators)]

# %%
df_results.columns
# Out:
# Index(['MODEL', 'R2_TR', 'R2_TE', 'MAE_TR', 'MAE_TE', 'MODEL_OBJ', 'IN', 'OUT',
#        'RMSE_TR', 'RMSE_TE', 'CASE', 'ESTIMATOR'],
#       dtype='object')

# %% [markdown]
# Removendo duplicatas do caso base que ficou repetido

# %%
df_results['CASE'].value_counts()
# Out:
# CASE
# ENSEMBLE    256
# BASE         64
# FEAT_DEC     32
# Name: count, dtype: int64

# %%
df_results = df_results.drop_duplicates(subset=['MODEL','IN', 'OUT','CASE'])
df_results['CASE'].value_counts()
# Out:
# CASE
# ENSEMBLE    256
# FEAT_DEC     32
# BASE         32
# Name: count, dtype: int64

# %% [markdown]
# Reordering columns

# %%
new_cols = [
    'CASE',
    'MODEL',
    'ESTIMATOR',
    'R2_TR',
    'R2_TE',
    'RMSE_TR',
    'RMSE_TE',
    # 'MAE_TR',
    # 'MAE_TE',
    'MODEL_OBJ',
    'IN',
    'OUT',
]
df_results = df_results[new_cols]
df_results
# Out:
#          CASE                     MODEL ESTIMATOR     R2_TR     R2_TE  \
# 0    FEAT_DEC              PolyReg(DEC)   PolyReg  0.846082  0.903419
# 1    ENSEMBLE                   SVM.SVM       SVM  0.843406  0.852442
# 2    ENSEMBLE               MLP.XGBoost       MLP  0.959644  0.850101
# 3    ENSEMBLE                   MLP.MLP       MLP  0.924926  0.849657
# 4    ENSEMBLE                   SVM.MLP       SVM  0.844872  0.847915
# ..        ...                       ...       ...       ...       ...
# 378  ENSEMBLE                LinReg.MLP    LinReg  0.783353  0.453069
# 379  ENSEMBLE       LinReg.RandomForest    LinReg  0.848532  0.452852
# 380  ENSEMBLE  LinReg.AdaBoostRegressor    LinReg  0.797514  0.445099
# 381  ENSEMBLE                LinReg.SVM    LinReg  0.781750  0.440163
# 382  ENSEMBLE            LinReg.XGBoost    LinReg  0.806440  0.430511
#
#       RMSE_TR   RMSE_TE                                          MODEL_OBJ  \
# 0    0.084848  0.057283  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 1    0.085583  0.070805  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 2    0.036095  0.057352  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 3    0.049231  0.057437  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 4    0.085181  0.071883  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# ..        ...       ...                                                ...
# 378  0.065633  0.098261  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 379  0.054879  0.098280  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 380  0.063451  0.098974  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 381  0.065875  0.099414  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 382  0.062037  0.100267  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
#
#                                   IN   OUT
# 0       GR.NPHI.RHOB.PHIF.RACEHM_LOG    DT
# 1       GR.NPHI.RHOB.PHIF.RACEHM_LOG    DT
# 2           DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 3           DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 4       GR.NPHI.RHOB.PHIF.RACEHM_LOG    DT
# ..                               ...   ...
# 378  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 379  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 380  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 381  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
# 382  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG  NPHI
#
# [320 rows x 10 columns]

# %% [markdown]
# Sumarização por classe

# %%
df_sum_class = df_results.drop_duplicates(subset=['CASE', 'OUT'])
df_sum_class = df_sum_class.sort_values(['OUT','R2_TE'], ascending=False).reset_index(drop=True)
df_sum_class
# Out:
#         CASE                 MODEL          ESTIMATOR     R2_TR     R2_TE  \
# 0   ENSEMBLE           MLP.XGBoost                MLP  0.959644  0.850101
# 1   FEAT_DEC              SVM(DEC)                SVM  0.916052  0.843549
# 2       BASE               PolyReg            PolyReg  0.909091  0.833406
# 3   FEAT_DEC              SVM(DEC)                SVM  0.910283  0.814786
# 4   ENSEMBLE  GradientBoosting.MLP   GradientBoosting  0.966459  0.782489
# 5       BASE               PolyReg            PolyReg  0.897169  0.777609
# 6   FEAT_DEC              MLP(DEC)                MLP  0.875294  0.838061
# 7   ENSEMBLE            MLP.LinReg                MLP  0.858956  0.822695
# 8       BASE                   MLP                MLP  0.843075  0.820392
# 9   FEAT_DEC          PolyReg(DEC)            PolyReg  0.846082  0.903419
# 10  ENSEMBLE               SVM.SVM                SVM  0.843406  0.852442
# 11      BASE     AdaBoostRegressor  AdaBoostRegressor  0.833461  0.818034
#
#      RMSE_TR   RMSE_TE                                          MODEL_OBJ  \
# 0   0.036095  0.057352  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 1   0.052060  0.058592  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 2   0.054175  0.060461  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 3   0.048342  0.066279  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 4   0.029558  0.071825  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 5   0.051754  0.072627  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 6   0.049795  0.053468  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 7   0.052957  0.055947  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 8   0.055858  0.056309  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 9   0.084848  0.057283  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 10  0.085583  0.070805  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 11  0.088258  0.078628  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
#
#                                  IN         OUT
# 0          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 1          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 2          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 3                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 4                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 5                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 6   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 7   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 8   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 9      GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 10     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 11     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT

# %% [markdown]
# Sumarização por modelo

# %%
df_sum_model = df_results.drop_duplicates(subset=['ESTIMATOR', 'OUT'])
df_sum_model = df_sum_model.sort_values(['OUT','R2_TE'], ascending=False).reset_index(drop=True)
df_sum_model
# Out:
#         CASE                     MODEL          ESTIMATOR     R2_TR     R2_TE  \
# 0   ENSEMBLE               MLP.XGBoost                MLP  0.959644  0.850101
# 1   FEAT_DEC                  SVM(DEC)                SVM  0.916052  0.843549
# 2       BASE                   PolyReg            PolyReg  0.909091  0.833406
# 3   ENSEMBLE               XGBoost.MLP            XGBoost  0.937864  0.794570
# 4   ENSEMBLE  LinReg.AdaBoostRegressor             LinReg  0.875863  0.786024
# 5       BASE          GradientBoosting   GradientBoosting  0.988800  0.760834
# 6       BASE              RandomForest       RandomForest  0.975829  0.736613
# 7       BASE         AdaBoostRegressor  AdaBoostRegressor  0.889069  0.643324
# 8   FEAT_DEC                  SVM(DEC)                SVM  0.910283  0.814786
# 9   FEAT_DEC                  MLP(DEC)                MLP  0.958814  0.788846
# 10  ENSEMBLE      GradientBoosting.MLP   GradientBoosting  0.966459  0.782489
# 11      BASE                   PolyReg            PolyReg  0.897169  0.777609
# 12  ENSEMBLE               XGBoost.MLP            XGBoost  0.972636  0.775985
# 13  ENSEMBLE          RandomForest.MLP       RandomForest  0.965543  0.770643
# 14  ENSEMBLE     AdaBoostRegressor.MLP  AdaBoostRegressor  0.899276  0.749841
# 15  FEAT_DEC               LinReg(DEC)             LinReg  0.887108  0.704794
# 16  FEAT_DEC                  MLP(DEC)                MLP  0.875294  0.838061
# 17      BASE                       SVM                SVM  0.805760  0.811180
# 18  ENSEMBLE          RandomForest.SVM       RandomForest  0.895108  0.778552
# 19  ENSEMBLE  AdaBoostRegressor.LinReg  AdaBoostRegressor  0.810100  0.749518
# 20  ENSEMBLE      GradientBoosting.SVM   GradientBoosting  0.904447  0.749275
# 21  FEAT_DEC              XGBoost(DEC)            XGBoost  0.999157  0.737099
# 22  ENSEMBLE           PolyReg.PolyReg            PolyReg  0.835946  0.655412
# 23      BASE                    LinReg             LinReg  0.757447  0.581893
# 24  FEAT_DEC              PolyReg(DEC)            PolyReg  0.846082  0.903419
# 25  ENSEMBLE                   SVM.SVM                SVM  0.843406  0.852442
# 26  ENSEMBLE     AdaBoostRegressor.SVM  AdaBoostRegressor  0.836428  0.840124
# 27  ENSEMBLE                LinReg.SVM             LinReg  0.836835  0.818712
# 28      BASE                   XGBoost            XGBoost  0.910483  0.811805
# 29  FEAT_DEC         RandomForest(DEC)       RandomForest  0.967020  0.800433
# 30  FEAT_DEC                  MLP(DEC)                MLP  0.865676  0.796644
# 31  FEAT_DEC     GradientBoosting(DEC)   GradientBoosting  0.983762  0.746783
#
#      RMSE_TR   RMSE_TE                                          MODEL_OBJ  \
# 0   0.036095  0.057352  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 1   0.052060  0.058592  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 2   0.054175  0.060461  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 3   0.044789  0.067140  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 4   0.063306  0.068522  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 5   0.019015  0.072443  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 6   0.027935  0.076023  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 7   0.059845  0.088468  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 8   0.048342  0.066279  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 9   0.032753  0.070768  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 10  0.029558  0.071825  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 11  0.051754  0.072627  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 12  0.026698  0.072892  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 13  0.029959  0.073756  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 14  0.051221  0.077028  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 15  0.054227  0.083676  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 16  0.049795  0.053468  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 17  0.062146  0.057735  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 18  0.045668  0.062525  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 19  0.061448  0.066497  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 20  0.043588  0.066529  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 21  0.004095  0.068126  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 22  0.057113  0.077995  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 23  0.069446  0.085913  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 24  0.084848  0.057283  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 25  0.085583  0.070805  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 26  0.087469  0.073701  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 27  0.087360  0.078481  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 28  0.064707  0.079962  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 29  0.039276  0.082343  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 30  0.079264  0.083121  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 31  0.027559  0.092753  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
#
#                                  IN         OUT
# 0          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 1          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 2          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 3          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 4          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 5          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 6          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 7          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 8                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 9                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 10               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 11               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 12               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 13               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 14               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 15               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 16  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 17  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 18  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 19  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 20  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 21  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 22  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 23  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 24     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 25     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 26     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 27     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 28     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 29     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 30     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 31     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT

# %% [markdown]
# ### Plotando

# %%
# dfbest = df_results.sort_values(['OUT','R2_TE'], ascending=False).reset_index(drop=True).groupby('OUT')
# dfbest = df_results.sort_values(['OUT','R2_TE'], ascending=False).reset_index(drop=True).groupby(['CASE','OUT'])
dfbest = df_results.sort_values(['OUT','R2_TE'], ascending=False).reset_index(drop=True).groupby(['CASE','OUT'])
dfbest = dfbest.head(5)
dfbest
# Out:
#          CASE                    MODEL          ESTIMATOR     R2_TR     R2_TE  \
# 0    ENSEMBLE              MLP.XGBoost                MLP  0.959644  0.850101
# 1    ENSEMBLE                  MLP.MLP                MLP  0.924926  0.849657
# 2    ENSEMBLE               MLP.LinReg                MLP  0.926596  0.846713
# 3    ENSEMBLE    MLP.AdaBoostRegressor                MLP  0.938606  0.845082
# 4    ENSEMBLE              MLP.PolyReg                MLP  0.929074  0.844309
# 5    FEAT_DEC                 SVM(DEC)                SVM  0.916052  0.843549
# 9        BASE                  PolyReg            PolyReg  0.909091  0.833406
# 19       BASE                      MLP                MLP  0.925120  0.806355
# 21   FEAT_DEC                 MLP(DEC)                MLP  0.942623  0.804308
# 24       BASE                      SVM                SVM  0.883563  0.799980
# 36       BASE                  XGBoost            XGBoost  0.974254  0.778066
# 43   FEAT_DEC              LinReg(DEC)             LinReg  0.866501  0.769261
# 46       BASE         GradientBoosting   GradientBoosting  0.988800  0.760834
# 51   FEAT_DEC             PolyReg(DEC)            PolyReg  0.866976  0.727537
# 67   FEAT_DEC        RandomForest(DEC)       RandomForest  0.978052  0.690032
# 80   FEAT_DEC                 SVM(DEC)                SVM  0.910283  0.814786
# 81   FEAT_DEC                 MLP(DEC)                MLP  0.958814  0.788846
# 82   ENSEMBLE     GradientBoosting.MLP   GradientBoosting  0.966459  0.782489
# 83   FEAT_DEC    GradientBoosting(DEC)   GradientBoosting  0.990004  0.780239
# 84       BASE                  PolyReg            PolyReg  0.897169  0.777609
# 85   ENSEMBLE              XGBoost.MLP            XGBoost  0.972636  0.775985
# 86   ENSEMBLE              PolyReg.MLP            PolyReg  0.940577  0.774777
# 87   ENSEMBLE  GradientBoosting.LinReg   GradientBoosting  0.966856  0.774729
# 88   ENSEMBLE                  MLP.MLP                MLP  0.955865  0.772711
# 93       BASE                      SVM                SVM  0.889388  0.767705
# 94   FEAT_DEC        RandomForest(DEC)       RandomForest  0.986066  0.767213
# 96   FEAT_DEC             PolyReg(DEC)            PolyReg  0.952126  0.766658
# 101      BASE                      MLP                MLP  0.903456  0.763477
# 107      BASE         GradientBoosting   GradientBoosting  0.980259  0.761745
# 111      BASE                  XGBoost            XGBoost  0.955421  0.759265
# 160  FEAT_DEC                 MLP(DEC)                MLP  0.875294  0.838061
# 161  ENSEMBLE               MLP.LinReg                MLP  0.858956  0.822695
# 162      BASE                      MLP                MLP  0.843075  0.820392
# 163  ENSEMBLE              MLP.PolyReg                MLP  0.870400  0.820126
# 164  ENSEMBLE                  MLP.SVM                MLP  0.857496  0.818536
# 165  ENSEMBLE                  MLP.MLP                MLP  0.862111  0.817957
# 166      BASE                      SVM                SVM  0.805760  0.811180
# 167  ENSEMBLE         MLP.RandomForest                MLP  0.923518  0.810414
# 174  FEAT_DEC        RandomForest(DEC)       RandomForest  0.962070  0.772960
# 179      BASE             RandomForest       RandomForest  0.951188  0.763105
# 180  FEAT_DEC                 SVM(DEC)                SVM  0.831163  0.762165
# 190      BASE        AdaBoostRegressor  AdaBoostRegressor  0.811053  0.737848
# 192  FEAT_DEC             XGBoost(DEC)            XGBoost  0.999157  0.737099
# 194  FEAT_DEC    GradientBoosting(DEC)   GradientBoosting  0.984502  0.734648
# 200      BASE                  XGBoost            XGBoost  0.981021  0.730362
# 240  FEAT_DEC             PolyReg(DEC)            PolyReg  0.846082  0.903419
# 241  ENSEMBLE                  SVM.SVM                SVM  0.843406  0.852442
# 242  ENSEMBLE                  SVM.MLP                SVM  0.844872  0.847915
# 243  ENSEMBLE              SVM.PolyReg                SVM  0.843652  0.846300
# 244  ENSEMBLE               SVM.LinReg                SVM  0.846253  0.844257
# 245  ENSEMBLE              SVM.XGBoost                SVM  0.860108  0.843387
# 257  FEAT_DEC                 SVM(DEC)                SVM  0.859587  0.827412
# 259      BASE        AdaBoostRegressor  AdaBoostRegressor  0.833461  0.818034
# 261  FEAT_DEC   AdaBoostRegressor(DEC)  AdaBoostRegressor  0.847296  0.812792
# 262      BASE                  XGBoost            XGBoost  0.910483  0.811805
# 263  FEAT_DEC              LinReg(DEC)             LinReg  0.838706  0.809467
# 267      BASE                      SVM                SVM  0.843019  0.807220
# 271  FEAT_DEC        RandomForest(DEC)       RandomForest  0.967020  0.800433
# 275      BASE                   LinReg             LinReg  0.817558  0.791211
# 282      BASE             RandomForest       RandomForest  0.932981  0.782344
#
#       RMSE_TR   RMSE_TE                                          MODEL_OBJ  \
# 0    0.036095  0.057352  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 1    0.049231  0.057437  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 2    0.048681  0.057996  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 3    0.044521  0.058304  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 4    0.047852  0.058449  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 5    0.052060  0.058592  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 9    0.054175  0.060461  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 19   0.049168  0.065185  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 21   0.043040  0.065529  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 24   0.061312  0.066250  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 36   0.028831  0.069785  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 43   0.065650  0.071155  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 46   0.019015  0.072443  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 51   0.065533  0.077322  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 67   0.026619  0.082472  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 80   0.048342  0.066279  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 81   0.032753  0.070768  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 82   0.029558  0.071825  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 83   0.016136  0.072196  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 84   0.051754  0.072627  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 85   0.026698  0.072892  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 86   0.039342  0.073088  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 87   0.029382  0.073096  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 88   0.033906  0.073422  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 93   0.053677  0.074226  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 94   0.019051  0.074305  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 96   0.035313  0.074394  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 101  0.050147  0.074899  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 107  0.022676  0.075173  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 111  0.034076  0.075563  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 160  0.049795  0.053468  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 161  0.052957  0.055947  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 162  0.055858  0.056309  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 163  0.050763  0.056351  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 164  0.053230  0.056599  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 165  0.052361  0.056689  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 166  0.062146  0.057735  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 167  0.038996  0.057852  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 174  0.027462  0.063309  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 179  0.031153  0.064668  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 180  0.057940  0.064797  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 190  0.061293  0.068029  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 192  0.004095  0.068126  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 194  0.017554  0.068442  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 200  0.019426  0.068993  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 240  0.084848  0.057283  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 241  0.085583  0.070805  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 242  0.085181  0.071883  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 243  0.085515  0.072264  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 244  0.084801  0.072742  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 245  0.080890  0.072945  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 257  0.081040  0.076575  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 259  0.088258  0.078628  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 261  0.084513  0.079752  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 262  0.064707  0.079962  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 263  0.086858  0.080458  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 267  0.085688  0.080931  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 271  0.039276  0.082343  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 275  0.092376  0.084224  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 282  0.055988  0.085994  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
#
#                                   IN         OUT
# 0           DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 1           DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 2           DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 3           DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 4           DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 5           DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 9           DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 19          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 21          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 24          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 36          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 43          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 46          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 51          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 67          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 80                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 81                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 82                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 83                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 84                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 85                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 86                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 87                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 88                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 93                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 94                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 96                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 101               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 107               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 111               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 160  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 161  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 162  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 163  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 164  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 165  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 166  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 167  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 174  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 179  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 180  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 190  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 192  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 194  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 200  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 240     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 241     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 242     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 243     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 244     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 245     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 257     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 259     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 261     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 262     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 263     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 267     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 271     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 275     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 282     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT

# %%
myPalette = ['r', '0.3', '#4169E1']

# %%
lim=(0.6,1)
figsize = (10,8)

fig, ax = plt.subplots(2, 2, figsize=figsize)
ax = ax.flat

# fig.suptitle('')

for i, var in enumerate(df_results['OUT'].unique()):
    sns.barplot(data=dfbest[dfbest['OUT']==var], x='R2_TE', y='MODEL', hue='CASE', ax=ax[i], hue_order=dfbest['CASE'].unique()[::-1], palette=myPalette, alpha=0.8);
    ax[i].set_title(f' Predictions for {var} log')
    ax[i].set_xlabel('$R^2$ Test')
    ax[i].set_ylabel('Model')
    ax[i].legend(loc='lower right')
    ax[i].set_xlim(lim)
    plt.tight_layout()

fig.savefig(f'./Images/bars_model_5bestPerClass_short.pdf', format='pdf')

# %%
lim=(0.5,1)
# lim=(0.5,.91)
figsize = (10,8)

fig, ax = plt.subplots(2, 2, figsize=figsize)
ax = ax.flat

for i, var in enumerate(df_results['OUT'].unique()):
    # sns.barplot(data=df_sum_model[df_sum_model['OUT']==var], x='R2_TE', y='ESTIMATOR', hue='CASE', ax=ax[i], hue_order=dfbest['CASE'].unique()[::-1], palette=myPalette, alpha=0.8);
    sns.barplot(data=df_sum_model[df_sum_model['OUT']==var], x='R2_TE', y='ESTIMATOR', hue='ESTIMATOR', hue_order=df_results['ESTIMATOR'].unique(), ax=ax[i], palette='Paired');
    ax[i].set_title(f' Predictions for {var} log')
    ax[i].set_xlabel('$R^2$ Test')
    ax[i].set_ylabel('Estimator')
    ax[i].set_xlim(lim)
    plt.tight_layout()

fig.savefig(f'./Images/bars_estimator_short.pdf', format='pdf')

# %%
lim=(0.75,0.91)
figsize = (10,6)

fig, ax = plt.subplots(2, 2, figsize=figsize)
ax = ax.flat

for i, var in enumerate(df_results['OUT'].unique()):
    sns.barplot(data=df_sum_class[df_sum_class['OUT']==var], x='R2_TE', y='MODEL', hue='CASE', ax=ax[i], palette=myPalette, hue_order=dfbest['CASE'].unique()[::-1], alpha=0.8);
    ax[i].set_title(f'Best Predictions for {var} log')
    ax[i].set_xlabel('$R^2$ Test')
    ax[i].set_ylabel('Best Model')
    ax[i].legend(loc='lower right')
    # if i==3: ax[i].legend(loc='lower right')
    ax[i].set_xlim(lim)
    plt.tight_layout()

fig.savefig(f'./Images/bars_best_models_short.pdf', format='pdf')

# %% [markdown]
# Predições dos melhores casos

# %%
df = pd.read_csv('./Data/volve_preproc.csv')
df.shape
# Out:
# (23733, 10)

# %%
def decomp(X_te, period=10):
    extrapolate_trend = 5
    return seasonal_decompose(X_te, period=period, extrapolate_trend=extrapolate_trend)

# %%
df_results['OUT'].unique().tolist()
# Out:
# ['DT', 'RHOB', 'NPHI', 'RACEHM_LOG']

# %%
df_results.columns
# Out:
# Index(['CASE', 'MODEL', 'ESTIMATOR', 'R2_TR', 'R2_TE', 'RMSE_TR', 'RMSE_TE',
#        'MODEL_OBJ', 'IN', 'OUT'],
#       dtype='object')

# %%
df_results.groupby(['IN', 'OUT']).head(1)[['IN','OUT']]
# Out:
#                                  IN         OUT
# 0      GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 2          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 19  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 48               DT.GR.NPHI.RHOB.SW  RACEHM_LOG

# %%
data_dict = {
    'DT' :  [],
    'RHOB': [],
    'NPHI': [],
    'RACEHM_LOG': [],
}

# DT
n=3
df2 = df[::n]
df_filt = df2.dropna()
test_wells = ['15/9-F-1 B']
test_df = df_filt[df_filt['wellName'].isin(test_wells)]
inputs = ['GR','NPHI','RHOB','PHIF','RACEHM_LOG']
output = ['DT']
X_te = test_df[inputs]
y_te = test_df[output]
X_te = X_te.values
y_te = y_te.values
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
X_te = X_scaler.fit_transform(X_te)
y_te = y_scaler.fit_transform(y_te)
X_te_dec = decomp(X_te,period=10)
X2_te = np.concatenate([X_te_dec.trend,X_te_dec.seasonal+X_te_dec.resid], axis=1)

data_dict['DT'].append(X_te)
data_dict['DT'].append(X_te_dec)
data_dict['DT'].append(X2_te)
data_dict['DT'].append(y_te)
data_dict['DT'].append(test_df['MD'])

# NPHI
test_df = df_filt[df_filt['wellName'].isin(test_wells)]
inputs = ['CALI','DT','GR','RHOB','PHIF','RACEHM_LOG']
output = ['NPHI']
X_te = test_df[inputs]
y_te = test_df[output]
X_te = X_te.values
y_te = y_te.values
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
X_te = X_scaler.fit_transform(X_te)
y_te = y_scaler.fit_transform(y_te)
X_te_dec = decomp(X_te,period=10)
X2_te = np.concatenate([X_te_dec.trend,X_te_dec.seasonal+X_te_dec.resid], axis=1)

data_dict['NPHI'].append(X_te)
data_dict['NPHI'].append(X_te_dec)
data_dict['NPHI'].append(X2_te)
data_dict['NPHI'].append(y_te)
data_dict['NPHI'].append(test_df['MD'])


# RACEHM_LOG
test_df = df_filt[df_filt['wellName'].isin(test_wells)]
inputs = ['DT','GR','NPHI','RHOB','SW']
output = ['RACEHM_LOG']
X_te = test_df[inputs]
y_te = test_df[output]
X_te = X_te.values
y_te = y_te.values
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
X_te = X_scaler.fit_transform(X_te)
y_te = y_scaler.fit_transform(y_te)
X_te_dec = decomp(X_te,period=10)
X2_te = np.concatenate([X_te_dec.trend,X_te_dec.seasonal+X_te_dec.resid], axis=1)

data_dict['RACEHM_LOG'].append(X_te)
data_dict['RACEHM_LOG'].append(X_te_dec)
data_dict['RACEHM_LOG'].append(X2_te)
data_dict['RACEHM_LOG'].append(y_te)
data_dict['RACEHM_LOG'].append(test_df['MD'])

# RHOB
n=4
df2 = df[::n]
df_filt = df2.dropna()
test_df = df_filt[df_filt['wellName'].isin(test_wells)]
inputs = ['DT','GR','NPHI','SW','RACEHM_LOG']
output = ['RHOB']
X_te = test_df[inputs]
y_te = test_df[output]
X_te = X_te.values
y_te = y_te.values
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
X_te = X_scaler.fit_transform(X_te)
y_te = y_scaler.fit_transform(y_te)
X_te_dec = decomp(X_te,period=10)
X2_te = np.concatenate([X_te_dec.trend,X_te_dec.seasonal+X_te_dec.resid], axis=1)

data_dict['RHOB'].append(X_te)
data_dict['RHOB'].append(X_te_dec)
data_dict['RHOB'].append(X2_te)
data_dict['RHOB'].append(y_te)
data_dict['RHOB'].append(test_df['MD'])

# %% [markdown]
# PLots

# %%
df_sum_class
# Out:
#         CASE                 MODEL          ESTIMATOR     R2_TR     R2_TE  \
# 0   ENSEMBLE           MLP.XGBoost                MLP  0.959644  0.850101
# 1   FEAT_DEC              SVM(DEC)                SVM  0.916052  0.843549
# 2       BASE               PolyReg            PolyReg  0.909091  0.833406
# 3   FEAT_DEC              SVM(DEC)                SVM  0.910283  0.814786
# 4   ENSEMBLE  GradientBoosting.MLP   GradientBoosting  0.966459  0.782489
# 5       BASE               PolyReg            PolyReg  0.897169  0.777609
# 6   FEAT_DEC              MLP(DEC)                MLP  0.875294  0.838061
# 7   ENSEMBLE            MLP.LinReg                MLP  0.858956  0.822695
# 8       BASE                   MLP                MLP  0.843075  0.820392
# 9   FEAT_DEC          PolyReg(DEC)            PolyReg  0.846082  0.903419
# 10  ENSEMBLE               SVM.SVM                SVM  0.843406  0.852442
# 11      BASE     AdaBoostRegressor  AdaBoostRegressor  0.833461  0.818034
#
#      RMSE_TR   RMSE_TE                                          MODEL_OBJ  \
# 0   0.036095  0.057352  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 1   0.052060  0.058592  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 2   0.054175  0.060461  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 3   0.048342  0.066279  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 4   0.029558  0.071825  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 5   0.051754  0.072627  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 6   0.049795  0.053468  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 7   0.052957  0.055947  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 8   0.055858  0.056309  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 9   0.084848  0.057283  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 10  0.085583  0.070805  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 11  0.088258  0.078628  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
#
#                                  IN         OUT
# 0          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 1          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 2          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 3                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 4                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 5                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 6   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 7   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 8   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 9      GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 10     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 11     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT

# %%
def y_pred(row):
    if row['CASE'] == 'ENSEMBLE':
        y_pred = row['MODEL_OBJ'][0].predict(data_dict[row['OUT']][1].trend) + row['MODEL_OBJ'][1].predict(data_dict[row['OUT']][1].seasonal+data_dict[row['OUT']][1].resid)
    elif row['CASE'] == 'FEAT_DEC':
        y_pred = row['MODEL_OBJ'].predict(data_dict[row['OUT']][2])
    else:
        y_pred = row['MODEL_OBJ'].predict(data_dict[row['OUT']][0])
    return y_pred.ravel()

def y_test(row):
    return data_dict[row['OUT']][3].ravel()

def train_time(row):
    search = row['MODEL_OBJ']
    if row['CASE'] == 'ENSEMBLE':
        tt = search[0].cv_results_['mean_fit_time'][search[0].best_index_] + search[1].cv_results_['mean_fit_time'][search[1].best_index_]
        # tt = np.mean(search[0].cv_results_['mean_fit_time']) + np.mean(search[1].cv_results_['mean_fit_time'])
    else:
        tt = search.cv_results_['mean_fit_time'][search.best_index_]
        # tt = np.mean(search.cv_results_['mean_fit_time'][search.best_index_])
    return tt

# %%
df_sum_class['y_pred'] = df_sum_class.apply(y_pred, axis=1)
df_sum_model['y_pred'] = df_sum_model.apply(y_pred, axis=1)
df_results['y_pred'] = df_results.apply(y_pred, axis=1)

df_sum_model['y_test'] = df_sum_model.apply(y_test, axis=1)
df_sum_class['y_test'] = df_sum_class.apply(y_test, axis=1)
df_results['y_test'] = df_results.apply(y_test, axis=1)

df_sum_class['train_time'] = df_sum_class.apply(train_time, axis=1)
df_sum_model['train_time'] = df_sum_model.apply(train_time, axis=1)
df_results['train_time'] = df_results.apply(train_time, axis=1)
df_sum_class[['CASE','OUT','train_time']]
# Out:
#         CASE         OUT  train_time
# 0   ENSEMBLE        RHOB    1.307467
# 1   FEAT_DEC        RHOB    0.025078
# 2       BASE        RHOB    0.002711
# 3   FEAT_DEC  RACEHM_LOG    0.017372
# 4   ENSEMBLE  RACEHM_LOG    2.820688
# 5       BASE  RACEHM_LOG    0.003299
# 6   FEAT_DEC        NPHI    1.011227
# 7   ENSEMBLE        NPHI    4.352604
# 8       BASE        NPHI    1.632815
# 9   FEAT_DEC          DT    0.007272
# 10  ENSEMBLE          DT    0.037380
# 11      BASE          DT    0.448719

# %%
lim=(0,1)

fig, ax = plt.subplots(2,2, figsize=(7,7))

plt.subplot(221)
sns.scatterplot(x=df_sum_class.iloc[0,-2].ravel(), y=df_sum_class.iloc[0,-3].ravel(), s=50, color='.3')
plt.plot(lim, lim, 'r--', label='$\hat{y}=y$')
plt.xlim(lim)
plt.ylim(lim)
plt.xlabel('$y$ - observed')
plt.ylabel('$\hat{y}$ - predictions')
plt.legend(loc='upper left')
plt.title(f"{df_sum_class.loc[0,'OUT']} preditions: R²:{df_sum_class.loc[0,'R2_TE']:.3f}\n {df_sum_class.loc[0,'CASE']} model {df_sum_class.loc[0,'MODEL']}")
plt.tight_layout()

plt.subplot(222)
sns.scatterplot(x=df_sum_class.iloc[3,-2].ravel(), y=df_sum_class.iloc[3,-3].ravel(), s=50, color='.3')
plt.plot(lim, lim, 'r--', label='$\hat{y}=y$')
plt.xlim(lim)
plt.ylim(lim)
plt.xlabel('$y$ - observed')
plt.ylabel('$\hat{y}$ - predictions')
plt.legend(loc='upper left')
plt.title(f"{df_sum_class.loc[3,'OUT']} preditions: R²:{df_sum_class.loc[3,'R2_TE']:.3f}\n {df_sum_class.loc[3,'CASE']} model {df_sum_class.loc[3,'MODEL']}")
plt.tight_layout()

plt.subplot(223)
sns.scatterplot(x=df_sum_class.iloc[6,-2].ravel(), y=df_sum_class.iloc[6,-3].ravel(), s=50, color='.3')
plt.plot(lim, lim, 'r--', label='$\hat{y}=y$')
plt.xlim(lim)
plt.ylim(lim)
plt.xlabel('$y$ - observed')
plt.ylabel('$\hat{y}$ - predictions')
plt.legend(loc='upper left')
plt.title(f"{df_sum_class.loc[6,'OUT']} preditions: R²:{df_sum_class.loc[6,'R2_TE']:.3f}\n {df_sum_class.loc[6,'CASE']} model {df_sum_class.loc[6,'MODEL']}")
plt.tight_layout()

plt.subplot(224)
sns.scatterplot(x=df_sum_class.iloc[9,-2].ravel(), y=df_sum_class.iloc[9,-3].ravel(), s=50, color='.3')
plt.plot(lim, lim, 'r--', label='$\hat{y}=y$')
plt.xlim(lim)
plt.ylim(lim)
plt.xlabel('$y$ - observed')
plt.ylabel('$\hat{y}$ - predictions')
plt.legend(loc='upper left')
plt.title(f"{df_sum_class.loc[9,'OUT']} preditions: R²:{df_sum_class.loc[9,'R2_TE']:.3f}\n {df_sum_class.loc[9,'CASE']} model {df_sum_class.loc[9,'MODEL']}")
plt.tight_layout()

pass;
fig.savefig(f'./Images/crossplot_science_short.pdf', format='pdf')

# %%
depth_range = [None,None]
for variable in df_sum_class['OUT'].unique():
    dftemp = df_sum_class[df_sum_class['OUT'] == variable]
    dftemp = dftemp.sort_values(['CASE']).reset_index(drop=True)

    base_row = dftemp.loc[0,:]
    featdec_row = dftemp.loc[2,:]
    ensemble_row = dftemp.loc[1,:]

    y_hat_base = base_row['y_pred']
    y_hat_featdec = featdec_row['y_pred']
    y_hat_hybrid = ensemble_row['y_pred']
    # y_hat_base = base_row['MODEL_OBJ'].predict(data_dict[variable][0])
    # y_hat_featdec = featdec_row['MODEL_OBJ'].predict(data_dict[variable][2])
    # y_hat_hybrid = ensemble_row['MODEL_OBJ'][0].predict(data_dict[variable][1].trend) + ensemble_row['MODEL_OBJ'][1].predict(data_dict[variable][1].seasonal+data_dict[variable][1].resid)

    fig, ax = plt.subplots(1,4, figsize=(12,9))

    y_real = data_dict[variable][-2].ravel()
    depth  = data_dict[variable][-1]

    plt.subplot(141)
    plt.plot(y_real, depth, 'o', color='#999999', label='$y$');
    plt.plot(y_hat_base, depth, 'r', lw=2, label='$\hat{y}$')
    plt.title(f'Best Base Model \n {base_row["MODEL"]} ($R^2$={r2_score(y_real, y_hat_base):.3f})')
    plt.xlabel(f'Normalized {variable}')
    plt.gca().invert_yaxis()
    plt.grid()
    plt.ylabel('Depth[m]')
    plt.legend(loc='best')
    plt.tight_layout()
    plt.ylim(depth_range)

    plt.subplot(142)
    plt.plot(y_real, depth, 'o', color='#999999', label='$y$');
    plt.plot(y_hat_featdec, depth, 'k', lw=2, label='$\hat{y}$')
    plt.gca().invert_yaxis()
    plt.title(f'Best Feat. Decomp. Model \n {featdec_row["MODEL"]} ($R^2$={r2_score(y_real, y_hat_featdec):.3f})')
    plt.xlabel(f'Normalized {variable}')
    plt.grid()
    plt.legend(loc='best')
    plt.tight_layout()
    plt.ylim(depth_range)

    plt.subplot(143)
    plt.plot(y_real, depth, 'o', color='#999999', label='$y$');
    plt.plot(y_hat_hybrid,  depth, 'b', lw=2, label='$\hat{y}$')
    plt.gca().invert_yaxis()
    plt.title(f'Best Ensemble Model \n {ensemble_row["MODEL"]} ($R^2$={r2_score(y_real, y_hat_hybrid):.3f})')
    plt.xlabel(f'Normalized {variable}')
    plt.grid()
    plt.legend(loc='best')
    plt.tight_layout()
    plt.ylim(depth_range)

    plt.subplot(144)
    plt.plot(y_real - y_hat_base, depth, 'r', lw=2, label='Base')
    plt.plot(y_real - y_hat_featdec, depth, 'k', lw=2, label='Feat. Dec.')
    plt.plot(y_real - y_hat_hybrid, depth, 'b', lw=2, label='Ensemble')
    plt.gca().invert_yaxis()
    plt.title('Best Models Error Plot')
    plt.xlabel(f'{variable}' + ' prediction error ($y-\hat{y}$)')
    plt.grid()
    plt.legend(loc='best', bbox_to_anchor=(0.5, 0.4))

    plt.tight_layout()
    plt.ylim(depth_range)

    fig.savefig(f'./Images/pred_{variable}_science_short_err.pdf', format='pdf')

# %%
filt = [
'OUT',
'CASE',
'MODEL',
'R2_TR',
'R2_TE',
'RMSE_TR',
'RMSE_TE',
'train_time',
]
df_sum_class[filt].round(5).to_clipboard()

# %%
idx = df_results.groupby(['OUT', 'ESTIMATOR'])['R2_TE'].idxmax()
df_best_estim = df_results.loc[idx]

df_best_estim
# Out:
#          CASE                     MODEL          ESTIMATOR     R2_TR  \
# 15   ENSEMBLE     AdaBoostRegressor.SVM  AdaBoostRegressor  0.836428
# 193  FEAT_DEC     GradientBoosting(DEC)   GradientBoosting  0.983762
# 43   ENSEMBLE                LinReg.SVM             LinReg  0.836835
# 81   FEAT_DEC                  MLP(DEC)                MLP  0.865676
# 0    FEAT_DEC              PolyReg(DEC)            PolyReg  0.846082
# 73   FEAT_DEC         RandomForest(DEC)       RandomForest  0.967020
# 1    ENSEMBLE                   SVM.SVM                SVM  0.843406
# 51       BASE                   XGBoost            XGBoost  0.910483
# 188  ENSEMBLE  AdaBoostRegressor.LinReg  AdaBoostRegressor  0.810100
# 189  ENSEMBLE      GradientBoosting.SVM   GradientBoosting  0.904447
# 359      BASE                    LinReg             LinReg  0.757447
# 19   FEAT_DEC                  MLP(DEC)                MLP  0.875294
# 321  ENSEMBLE           PolyReg.PolyReg            PolyReg  0.835946
# 110  ENSEMBLE          RandomForest.SVM       RandomForest  0.895108
# 53       BASE                       SVM                SVM  0.805760
# 211  FEAT_DEC              XGBoost(DEC)            XGBoost  0.999157
# 187  ENSEMBLE     AdaBoostRegressor.MLP  AdaBoostRegressor  0.899276
# 101  ENSEMBLE      GradientBoosting.MLP   GradientBoosting  0.966459
# 284  FEAT_DEC               LinReg(DEC)             LinReg  0.887108
# 92   FEAT_DEC                  MLP(DEC)                MLP  0.958814
# 115      BASE                   PolyReg            PolyReg  0.897169
# 131  ENSEMBLE          RandomForest.MLP       RandomForest  0.965543
# 48   FEAT_DEC                  SVM(DEC)                SVM  0.910283
# 121  ENSEMBLE               XGBoost.MLP            XGBoost  0.972636
# 327      BASE         AdaBoostRegressor  AdaBoostRegressor  0.889069
# 166      BASE          GradientBoosting   GradientBoosting  0.988800
# 97   ENSEMBLE  LinReg.AdaBoostRegressor             LinReg  0.875863
# 2    ENSEMBLE               MLP.XGBoost                MLP  0.959644
# 26       BASE                   PolyReg            PolyReg  0.909091
# 213      BASE              RandomForest       RandomForest  0.975829
# 10   FEAT_DEC                  SVM(DEC)                SVM  0.916052
# 84   ENSEMBLE               XGBoost.MLP            XGBoost  0.937864
#
#         R2_TE   RMSE_TR   RMSE_TE  \
# 15   0.840124  0.087469  0.073701
# 193  0.746783  0.027559  0.092753
# 43   0.818712  0.087360  0.078481
# 81   0.796644  0.079264  0.083121
# 0    0.903419  0.084848  0.057283
# 73   0.800433  0.039276  0.082343
# 1    0.852442  0.085583  0.070805
# 51   0.811805  0.064707  0.079962
# 188  0.749518  0.061448  0.066497
# 189  0.749275  0.043588  0.066529
# 359  0.581893  0.069446  0.085913
# 19   0.838061  0.049795  0.053468
# 321  0.655412  0.057113  0.077995
# 110  0.778552  0.045668  0.062525
# 53   0.811180  0.062146  0.057735
# 211  0.737099  0.004095  0.068126
# 187  0.749841  0.051221  0.077028
# 101  0.782489  0.029558  0.071825
# 284  0.704794  0.054227  0.083676
# 92   0.788846  0.032753  0.070768
# 115  0.777609  0.051754  0.072627
# 131  0.770643  0.029959  0.073756
# 48   0.814786  0.048342  0.066279
# 121  0.775985  0.026698  0.072892
# 327  0.643324  0.059845  0.088468
# 166  0.760834  0.019015  0.072443
# 97   0.786024  0.063306  0.068522
# 2    0.850101  0.036095  0.057352
# 26   0.833406  0.054175  0.060461
# 213  0.736613  0.027935  0.076023
# 10   0.843549  0.052060  0.058592
# 84   0.794570  0.044789  0.067140
#
#                                              MODEL_OBJ  \
# 15   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 193  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 43   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 81   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 0    RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 73   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 1    (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 51   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 188  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 189  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 359  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 19   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 321  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 110  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 53   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 211  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 187  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 101  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 284  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 92   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 115  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 131  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 48   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 121  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 327  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 166  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 97   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 2    (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 26   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 213  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 10   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 84   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
#
#                                   IN         OUT  \
# 15      GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 193     GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 43      GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 81      GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 0       GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 73      GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 1       GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 51      GR.NPHI.RHOB.PHIF.RACEHM_LOG          DT
# 188  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 189  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 359  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 19   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 321  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 110  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 53   CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 211  CALI.DT.GR.RHOB.PHIF.RACEHM_LOG        NPHI
# 187               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 101               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 284               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 92                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 115               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 131               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 48                DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 121               DT.GR.NPHI.RHOB.SW  RACEHM_LOG
# 327         DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 166         DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 97          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 2           DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 26          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 213         DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 10          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
# 84          DT.GR.NPHI.SW.RACEHM_LOG        RHOB
#
#                                                 y_pred  \
# 15   [0.6370593383449934, 0.6441645217094493, 0.665...
# 193  [0.5957501411822838, 0.6134204642053506, 0.634...
# 43   [0.6108200494135391, 0.6287381436873194, 0.660...
# 81   [0.6523320970413273, 0.6763319585638756, 0.711...
# 0    [0.6008521766614161, 0.6233392866595034, 0.658...
# 73   [0.6336279280431556, 0.6347463749475852, 0.639...
# 1    [0.6748976105709862, 0.6963896173229318, 0.732...
# 51   [0.6662895, 0.6642622, 0.7439971, 0.7320909, 0...
# 188  [0.4762610516582552, 0.5110866069377897, 0.543...
# 189  [0.5665097775496208, 0.5760670219298459, 0.579...
# 359  [0.4857656817092382, 0.5173771455474107, 0.544...
# 19   [0.5857069930542625, 0.5996601968801513, 0.605...
# 321  [0.5867320221957274, 0.6149636760043447, 0.642...
# 110  [0.6071924052037307, 0.614396105545942, 0.6255...
# 53   [0.5749030185542156, 0.6014934949468123, 0.609...
# 211  [0.53657436, 0.53431827, 0.51992005, 0.5094155...
# 187  [0.33335887221752974, 0.3280087988789609, 0.31...
# 101  [0.37224155599697734, 0.3706919867554916, 0.36...
# 284  [0.3706827560011261, 0.3602362831051773, 0.351...
# 92   [0.394881997175729, 0.39057652354731787, 0.387...
# 115  [0.3489823267756298, 0.33662157471122267, 0.33...
# 131  [0.3708948610327025, 0.36752416158238643, 0.36...
# 48   [0.4255004286955377, 0.4220703834277182, 0.425...
# 121  [0.3745196815482995, 0.3703163717728868, 0.364...
# 327  [0.42507041235364923, 0.4021523057579611, 0.38...
# 166  [0.4164187415637545, 0.4024897507585591, 0.431...
# 97   [0.40544212974265453, 0.3575997169297539, 0.36...
# 2    [0.45771955376311224, 0.447360316085328, 0.449...
# 26   [0.4337494027583047, 0.4271859918268128, 0.437...
# 213  [0.40909256136584016, 0.40753725313920036, 0.4...
# 10   [0.3819200679936834, 0.35854672653354025, 0.34...
# 84   [0.4662484190309985, 0.4474937539021912, 0.421...
#
#                                                 y_test  train_time
# 15   [0.7435146946794435, 0.7929273084479367, 0.824...    0.540295
# 193  [0.7435146946794435, 0.7929273084479367, 0.824...    2.847176
# 43   [0.7435146946794435, 0.7929273084479367, 0.824...    0.003255
# 81   [0.7435146946794435, 0.7929273084479367, 0.824...    0.806939
# 0    [0.7435146946794435, 0.7929273084479367, 0.824...    0.007272
# 73   [0.7435146946794435, 0.7929273084479367, 0.824...    0.767513
# 1    [0.7435146946794435, 0.7929273084479367, 0.824...    0.037380
# 51   [0.7435146946794435, 0.7929273084479367, 0.824...    0.043959
# 188  [0.4659057652911911, 0.4840503365525314, 0.528...    0.384118
# 189  [0.4659057652911911, 0.4840503365525314, 0.528...    2.596325
# 359  [0.4659057652911911, 0.4840503365525314, 0.528...    0.002336
# 19   [0.4659057652911911, 0.4840503365525314, 0.528...    1.011227
# 321  [0.4659057652911911, 0.4840503365525314, 0.528...    0.008934
# 110  [0.4659057652911911, 0.4840503365525314, 0.528...    0.347575
# 53   [0.4659057652911911, 0.4840503365525314, 0.528...    0.022636
# 211  [0.4659057652911911, 0.4840503365525314, 0.528...    0.911862
# 187  [0.3104570041814525, 0.304873375846967, 0.2947...    0.834831
# 101  [0.3104570041814525, 0.304873375846967, 0.2947...    2.820688
# 284  [0.3104570041814525, 0.304873375846967, 0.2947...    0.000719
# 92   [0.3104570041814525, 0.304873375846967, 0.2947...    1.941736
# 115  [0.3104570041814525, 0.304873375846967, 0.2947...    0.003299
# 131  [0.3104570041814525, 0.304873375846967, 0.2947...    0.891686
# 48   [0.3104570041814525, 0.304873375846967, 0.2947...    0.017372
# 121  [0.3104570041814525, 0.304873375846967, 0.2947...    0.491752
# 327  [0.44560972888541794, 0.42920897021086635, 0.4...    0.248142
# 166  [0.44560972888541794, 0.42920897021086635, 0.4...    2.343239
# 97   [0.44560972888541794, 0.42920897021086635, 0.4...    0.282844
# 2    [0.44560972888541794, 0.42920897021086635, 0.4...    1.307467
# 26   [0.44560972888541794, 0.42920897021086635, 0.4...    0.002711
# 213  [0.44560972888541794, 0.42920897021086635, 0.4...    0.413910
# 10   [0.44560972888541794, 0.42920897021086635, 0.4...    0.025078
# 84   [0.44560972888541794, 0.42920897021086635, 0.4...    0.561116

# %%
sns.catplot(data=df_best_estim, y='ESTIMATOR', x='R2_TE', hue='CASE', col='OUT', kind='bar', hue_order=['BASE', 'FEAT_DEC', 'ENSEMBLE'], palette=myPalette)
plt.xlim([0.5,1])
df_best_estim['CASE'].value_counts(), df_best_estim['CASE'].value_counts(normalize=True), 7/8, 6/8, 7/8, 4/8
# Out:
# (CASE
#  ENSEMBLE    14
#  FEAT_DEC    10
#  BASE         8
#  Name: count, dtype: int64,
#  CASE
#  ENSEMBLE    0.4375
#  FEAT_DEC    0.3125
#  BASE        0.2500
#  Name: proportion, dtype: float64,
#  0.875,
#  0.75,
#  0.875,
#  0.5)

# %% [markdown]
# heatmap dos vencedores

# %%
df_best_estim_pivot_r2 = df_best_estim.pivot(columns='OUT', values='R2_TE', index='ESTIMATOR')
df_best_estim_pivot_r2
# Out:
# OUT                      DT      NPHI  RACEHM_LOG      RHOB
# ESTIMATOR
# AdaBoostRegressor  0.840124  0.749518    0.749841  0.643324
# GradientBoosting   0.746783  0.749275    0.782489  0.760834
# LinReg             0.818712  0.581893    0.704794  0.786024
# MLP                0.796644  0.838061    0.788846  0.850101
# PolyReg            0.903419  0.655412    0.777609  0.833406
# RandomForest       0.800433  0.778552    0.770643  0.736613
# SVM                0.852442  0.811180    0.814786  0.843549
# XGBoost            0.811805  0.737099    0.775985  0.794570

# %%
# np.set_printoptions(precision=3, floatmode='fixed')
anr2 = df_best_estim_pivot_r2.values.round(2)
# anr2 = np.round(anr2,2)
anr2 = anr2.astype('str')
anr2[4,0] += '\nBest'
anr2[3,1] += '\nBest'
anr2[6,2] += '\nBest'
anr2[3,3] += '\nBest'
anr2
# Out:
# array([['0.84', '0.75', '0.75', '0.64'],
#        ['0.75', '0.75', '0.78', '0.76'],
#        ['0.82', '0.58', '0.7', '0.79'],
#        ['0.8', '0.84\nBest', '0.79', '0.85\nBest'],
#        ['0.9\nBest', '0.66', '0.78', '0.83'],
#        ['0.8', '0.78', '0.77', '0.74'],
#        ['0.85', '0.81', '0.81\nBest', '0.84'],
#        ['0.81', '0.74', '0.78', '0.79']], dtype='<U32')

# %%
myPalette = ['r', '0.6', '#4189E1']

# %%
df_best_estim_pivot = df_best_estim.pivot(columns='OUT', values='CASE', index='ESTIMATOR')
df_best_estim_pivot.replace({j:i for i,j in enumerate(['BASE', 'FEAT_DEC', 'ENSEMBLE'])}, inplace=True)

vmin = 0.33
vmax = 1.66

fig = plt.figure(figsize=(7,3))
ax = sns.heatmap(df_best_estim_pivot.T, cmap=myPalette, linewidths=1, annot=anr2.transpose(), fmt='s', annot_kws={'fontweight':'extra bold', 'size':11, 'color':'k'})
colorbar = ax.collections[0].colorbar
colorbar.set_ticks([vmin,1,vmax])
colorbar.set_ticklabels(['BASE', 'FEAT_DEC', 'ENSEMBLE'])

plt.ylabel('Well Log')
plt.xlabel('Estimator')
plt.xticks(rotation=30, ha='right')

fig.savefig(f'./Images/heatmap_best_estimators.pdf', format='pdf')

# %% [markdown]
# Crossplot Ensemble

# %%
def get_resid_model(row):
    if row['CASE'] == 'ENSEMBLE': resid_model = row['MODEL'].split('.')[1]
    else: resid_model = '-'
    return resid_model

# %%
vars = df_results['OUT'].unique().tolist()

for var in vars:
    print (var)
    df_base = df_results[(df_results['CASE'] == 'BASE') & (df_results['OUT'] == var)]
    df_ens  = df_results[(df_results['CASE'] == 'ENSEMBLE') & (df_results['OUT'] == var)]
    df_ens = pd.concat([df_ens, df_base], axis=0)[['CASE', 'MODEL', 'ESTIMATOR', 'R2_TE']]
    df_ens['RESID_MODEL'] = df_ens.apply(get_resid_model, axis=1)
    df_ens = df_ens.pivot(columns='RESID_MODEL', values='R2_TE', index='ESTIMATOR')

    fig = plt.figure(figsize=(9,5))
    sns.heatmap(df_ens, linewidths=1, annot=True, fmt='.3f', cmap='BrBG')
    plt.ylabel('Trend (or Base) Estimator')
    plt.xlabel('Seasonal + Residual Estimator')
    plt.xticks(rotation=45, ha='right')

    fig.axes[0].add_patch(plt.Rectangle((1, 0.1), 7.95, 7.8, ls='--', lw=2, ec='k', fc='none'))
    fig.savefig(f'./Images/heatmap_ens_results_{var}.pdf', format='pdf')
# Out:
# DT
# RHOB
# NPHI
# RACEHM_LOG

# %%
df_ens_all = df_results[df_results['CASE'].isin(['ENSEMBLE', 'BASE'])][['CASE', 'OUT', 'ESTIMATOR', 'R2_TE']].sort_values(by=['OUT', 'CASE'])

df_ens_all_max = df_ens_all.groupby(['OUT','ESTIMATOR','CASE' ])['R2_TE'].max().reset_index()

# g = sns.catplot(data=df_ens_all_max, x='R2_TE', y='ESTIMATOR', hue='CASE', col='OUT', kind='point', height=4, aspect=.6, palette='tab10');
g = sns.catplot(data=df_ens_all_max, x='R2_TE', y='ESTIMATOR', hue='CASE', col='OUT', kind='point', height=3, aspect=1.2, palette='tab10', col_wrap=2);
g.set_xlabels('$R^2(Test)$')
g.set_ylabels('Estimator')
for ax in g.axes.flatten(): ax.grid()

g.savefig('./Images/catplot_ens_results.pdf', format='pdf')

# %%
df_ens_all_max_pivot = df_ens_all_max.pivot(index=['OUT','ESTIMATOR'], columns=['CASE'], values='R2_TE').reset_index()
df_ens_all_max_pivot['IMPROVED'] = 1*(df_ens_all_max_pivot['ENSEMBLE'] > df_ens_all_max_pivot['BASE'])
# df_ens_all_max_pivot.groupby(['OUT']).sum()
df_ens_all_max_pivot
# Out:
# CASE         OUT          ESTIMATOR      BASE  ENSEMBLE  IMPROVED
# 0             DT  AdaBoostRegressor  0.818034  0.840124         1
# 1             DT   GradientBoosting  0.732892  0.735235         1
# 2             DT             LinReg  0.791211  0.818712         1
# 3             DT                MLP  0.615783  0.676808         1
# 4             DT            PolyReg  0.756749  0.738382         0
# 5             DT       RandomForest  0.782344  0.796782         1
# 6             DT                SVM  0.807220  0.852442         1
# 7             DT            XGBoost  0.811805  0.693906         0
# 8           NPHI  AdaBoostRegressor  0.737848  0.749518         1
# 9           NPHI   GradientBoosting  0.725867  0.749275         1
# 10          NPHI             LinReg  0.581893  0.480474         0
# 11          NPHI                MLP  0.820392  0.822695         1
# 12          NPHI            PolyReg  0.551464  0.655412         1
# 13          NPHI       RandomForest  0.763105  0.778552         1
# 14          NPHI                SVM  0.811180  0.613239         0
# 15          NPHI            XGBoost  0.730362  0.732993         1
# 16    RACEHM_LOG  AdaBoostRegressor  0.615545  0.749841         1
# 17    RACEHM_LOG   GradientBoosting  0.761745  0.782489         1
# 18    RACEHM_LOG             LinReg  0.641748  0.702217         1
# 19    RACEHM_LOG                MLP  0.763477  0.772711         1
# 20    RACEHM_LOG            PolyReg  0.777609  0.774777         0
# 21    RACEHM_LOG       RandomForest  0.738845  0.770643         1
# 22    RACEHM_LOG                SVM  0.767705  0.649190         0
# 23    RACEHM_LOG            XGBoost  0.759265  0.775985         1
# 24          RHOB  AdaBoostRegressor  0.643324  0.612984         0
# 25          RHOB   GradientBoosting  0.760834  0.722399         0
# 26          RHOB             LinReg  0.739660  0.786024         1
# 27          RHOB                MLP  0.806355  0.850101         1
# 28          RHOB            PolyReg  0.833406  0.806559         0
# 29          RHOB       RandomForest  0.736613  0.732708         0
# 30          RHOB                SVM  0.799980  0.833278         1
# 31          RHOB            XGBoost  0.778066  0.794570         1

# %% [markdown]
# Avaliação do FEATDEC

# %%
df_dec = df_results[df_results['CASE'].isin(['FEAT_DEC', 'BASE'])][['CASE', 'OUT', 'ESTIMATOR', 'R2_TE']].sort_values(by=['ESTIMATOR', 'OUT', 'CASE'])
df_dec.describe()
# Out:
#            R2_TE
# count  64.000000
# mean    0.744097
# std     0.080220
# min     0.493420
# 25%     0.729656
# 50%     0.762635
# 75%     0.800094
# max     0.903419

# %%
# g = sns.catplot(data=df_dec, x='R2_TE', y='ESTIMATOR', hue='CASE', col='OUT', kind='point', height=4, aspect=.6, palette='tab10');
g = sns.catplot(data=df_dec, x='R2_TE', y='ESTIMATOR', hue='CASE', col='OUT', kind='point', height=3, aspect=1.2, palette='tab10', col_wrap=2);
g.set_xlabels('$R^2(Test)$')
g.set_ylabels('Estimator')
# g.despine()
for ax in g.axes.flatten(): ax.grid()

g.savefig('./Images/catplot_featdec_results.pdf', format='pdf')

# %% [markdown]
# Estudo tempos totais de treino RSCV

# %%
def train_time_total(row):
    search = row['MODEL_OBJ']
    if row['CASE'] == 'ENSEMBLE':
        tt = np.sum(search[0].cv_results_['mean_fit_time']) + np.sum(search[1].cv_results_['mean_fit_time'])
    else:
        tt = np.sum(search.cv_results_['mean_fit_time'])
    return tt

# %%
df_results['train_time_total'] = df_results.apply(train_time_total, axis=1)

# %%
df_results.groupby(['CASE'])['train_time_total'].mean()

# df_results.groupby(['OUT','CASE'])['train_time_total'].mean()
# Out:
# CASE
# BASE        26.535485
# ENSEMBLE    59.772330
# FEAT_DEC    34.844608
# Name: train_time_total, dtype: float64

# %%
df_results['CASE'].value_counts()
# Out:
# CASE
# ENSEMBLE    256
# FEAT_DEC     32
# BASE         32
# Name: count, dtype: int64

# %%
# Out:
# 256
