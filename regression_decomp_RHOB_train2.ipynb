# %% [markdown]
# ### Bibliotecas

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import os
import pickle

from sklearn.preprocessing import MinMaxScaler, StandardScaler, PolynomialFeatures
from sklearn.model_selection import RepeatedKFold, RandomizedSearchCV
from sklearn.metrics import r2_score, mean_absolute_error

#Modelos
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.ensemble import StackingRegressor, VotingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import StackingRegressor
import lightgbm as lgb
import xgboost as xgb

from scipy import stats
from statsmodels.tsa.seasonal import seasonal_decompose
import itertools

from copy import deepcopy

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.simplefilter(action='ignore', category=SyntaxWarning)

# %% [markdown]
# ### Lendo Dados

# %%
df = pd.read_csv('./Data/volve_preproc.csv')
df.shape
# Out:
# (23733, 10)

# %% [markdown]
# #### Filtering Data

# %%
n=4
df2 = df[::n]
df2.shape
# Out:
# (5934, 10)

# %%
df_filt = df2.dropna()
df_filt.shape
# Out:
# (1330, 10)

# %%
df.groupby('wellName').count()
# Out:
#                 MD   CALI    DT     GR   NPHI   RHOB   PHIF     SW  RACEHM_LOG
# wellName
# 15/9-F-1 A    2099   2099  2099   2099   2099   2099   2099   2099        2099
# 15/9-F-1 B    1903   1903  1903   1903   1903   1903   1903   1903        1903
# 15/9-F-1 C    7631   7631     0   7631   7631   7631   7630   7630        7631
# 15/9-F-11 A   1402   1402  1402   1402   1402   1402   1321   1321        1402
# 15/9-F-11 B  10698  10698     0  10698  10698  10698  10698  10698       10698

# %%
df2.groupby('wellName').count()
# Out:
#                MD  CALI   DT    GR  NPHI  RHOB  PHIF    SW  RACEHM_LOG
# wellName
# 15/9-F-1 A    525   525  525   525   525   525   525   525         525
# 15/9-F-1 B    476   476  476   476   476   476   476   476         476
# 15/9-F-1 C   1908  1908    0  1908  1908  1908  1908  1908        1908
# 15/9-F-11 A   350   350  350   350   350   350   329   329         350
# 15/9-F-11 B  2675  2675    0  2675  2675  2675  2675  2675        2675

# %%
df_filt.groupby('wellName').count()
# Out:
#               MD  CALI   DT   GR  NPHI  RHOB  PHIF   SW  RACEHM_LOG
# wellName
# 15/9-F-1 A   525   525  525  525   525   525   525  525         525
# 15/9-F-1 B   476   476  476  476   476   476   476  476         476
# 15/9-F-11 A  329   329  329  329   329   329   329  329         329

# %% [markdown]
# ### Treinando modelo de ML para prever DT

# %% [markdown]
# #### Definindo a parcela de treino e de teste

# %%
training_wells = ['15/9-F-11 A', '15/9-F-1 A']
test_wells = ['15/9-F-1 B']
nodata_wells = ['15/9-F-11 B', '15/9-F-1 C'] #poços sem a informação de DT

# %%
train_df = df_filt[df_filt['wellName'].isin(training_wells)]
test_df = df_filt[df_filt['wellName'].isin(test_wells)]
nodata_df = df_filt[df_filt['wellName'].isin(nodata_wells)]

# %% [markdown]
# #### Selecionando variáveis de entrada e saída

# %%
inputs = [
    # 'CALI',
    'DT',
    'GR',
    'NPHI',
    # 'RHOB',
    # 'PHIF',
    'SW',
    'RACEHM_LOG'
    ]

output = ['RHOB']

# %%
X_tr = train_df[inputs]
y_tr = train_df[output]
X_te = test_df[inputs]
y_te = test_df[output]

# %%
X_tr.shape,y_tr.shape,X_te.shape,y_te.shape
# Out:
# ((854, 5), (854, 1), (476, 5), (476, 1))

# %%
X_tr = X_tr.values
X_te = X_te.values
y_tr = y_tr.values
y_te = y_te.values

# %% [markdown]
# #### Normalizando dados MinMax

# %%
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
X_tr = X_scaler.fit_transform(X_tr)
X_te = X_scaler.fit_transform(X_te)
y_tr = y_scaler.fit_transform(y_tr)
y_te = y_scaler.fit_transform(y_te)
# X_tr_dec_trend =    X_scaler.fit_transform(X_tr_dec.trend)
# X_te_dec_trend =    X_scaler.fit_transform(X_te_dec.trend)
# y_tr_dec_trend =    y_scaler.fit_transform(y_tr_dec.trend.reshape(-1, 1))
# y_te_dec_trend =    y_scaler.fit_transform(y_te_dec.trend.reshape(-1, 1))
# X_tr_dec_seasonal = X_scaler.fit_transform(X_tr_dec.seasonal)
# X_te_dec_seasonal = X_scaler.fit_transform(X_te_dec.seasonal)
# y_tr_dec_seasonal = y_scaler.fit_transform(y_tr_dec.seasonal.reshape(-1, 1))
# y_te_dec_seasonal = y_scaler.fit_transform(y_te_dec.seasonal.reshape(-1, 1))
# X_tr_dec_resid =    X_scaler.fit_transform(X_tr_dec.resid)
# X_te_dec_resid =    X_scaler.fit_transform(X_te_dec.resid)
# y_tr_dec_resid =    y_scaler.fit_transform(y_tr_dec.resid.reshape(-1, 1))
# y_te_dec_resid =    y_scaler.fit_transform(y_te_dec.resid.reshape(-1, 1))

# %% [markdown]
# #### Decomp

# %%
def decomp(X_tr,X_te,y_tr,y_te,period=50):
    extrapolate_trend = 5
    return seasonal_decompose(X_tr, period=period, extrapolate_trend=extrapolate_trend), seasonal_decompose(X_te, period=period, extrapolate_trend=extrapolate_trend), seasonal_decompose(y_tr, period=period, extrapolate_trend=extrapolate_trend), seasonal_decompose(y_te, period=period, extrapolate_trend=extrapolate_trend)

# %%
X_tr_dec, X_te_dec, y_tr_dec, y_te_dec = decomp(X_tr,X_te,y_tr,y_te,period=10)

# %%
for i in range(X_te_dec.trend.shape[1]):
    plt.figure()
    plt.plot(X_te[:,i], label='original')
    plt.plot(X_te_dec.trend[:,i], label='trend')
    # plt.plot(X_tr_dec.seasonal[:,i], label='seasonal')
    # plt.plot(X_tr_dec.resid[:,i], label='resid')
    plt.legend()
    pass;

X_te_dec.trend.shape, X_te.shape
# Out:
# ((476, 5), (476, 5))

# %% [markdown]
# Random State

# %%
rs=48

# %% [markdown]
# #### Declarando os Modelos ML

# %%
models_ml = [
    ('Linear'   ,'LinReg'              ,      LinearRegression(copy_X=True)), #ARX Equivalet
    ('NonLinear','PolyReg'             ,      Pipeline([('Poly', PolynomialFeatures(degree=2)), ('Reg', LinearRegression(copy_X=True))])), #NARX Equivale)t
    ('NonLinear','SVM'                 ,      SVR(max_iter=-1)),
    # ('NonLinear','KNN'                 ,      KNeighborsRegressor()),
    ('NonLinear','MLP'                 ,      MLPRegressor(random_state=rs)),
    # ('Ensembles','DecisionTree'        ,      DecisionTreeRegressor(random_state=rs)),
    ('Ensembles','RandomForest'        ,      RandomForestRegressor(random_state=rs)),
    ('Ensembles','GradientBoosting'    ,      GradientBoostingRegressor(random_state=rs)),
    # ('Ensembles','ExtraTrees'          ,      ExtraTreesRegressor(random_state=rs)),
    ('Ensembles','AdaBoostRegressor'   ,      AdaBoostRegressor(random_state=rs)),
    # ('Ensembles','BaggingRegressor'    ,      BaggingRegressor(random_state=rs)),
    # ('Ensembles','LightGBM'            ,      lgb.LGBMRegressor()),
    ('Ensembles','XGBoost'             ,      xgb.XGBRegressor()),
]

# %%
for i, m in enumerate(models_ml):
    print (i, m[2])
# Out:
# 0 LinearRegression()
# 1 Pipeline(steps=[('Poly', PolynomialFeatures()), ('Reg', LinearRegression())])
# 2 SVR()
# 3 MLPRegressor(random_state=48)
# 4 RandomForestRegressor(random_state=48)
# 5 GradientBoostingRegressor(random_state=48)
# 6 AdaBoostRegressor(random_state=48)
# 7 XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# #### Parâmetros (RandomSearchCV)

# %%
parameters = [
    { # LinReg 0
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'positive'                     : [True, False],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    { # PolyReg NARX 1
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'Reg__positive'                : [True, False],
        #'Poly__degree'                : [2, 3, 4, 5],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    { # SVM 2
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'C'                     : stats.loguniform(1e-3, 1e3),
        'kernel'                : ['poly', 'rbf', 'sigmoid'],
        'degree'                : stats.randint(2,6),
        'gamma'                 : stats.loguniform(1e-4, 1e0),
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    # { # KNN 3
    #     #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
    #     'n_neighbors'           : stats.randint(1,100),
    #     'weights'               : ['uniform', 'distance'],
    #     #'expansor'                    : [None, PolynomialFeatures(degree=2)],
    #     #'nX'                          : stats.randint(2,10),
    #     #'ny'                          : stats.randint(2,10),
    # },
    { # MLP 6
        'activation'            : ['relu', 'tanh'],
        'early_stopping'        : [True],
        'learning_rate_init'    : stats.loguniform(1e-4, 0.01),
        # 'learning_rate'         : ['adaptive', 'constant'],
        'alpha'                 : stats.loguniform(1e-5, 1e-3),
        'hidden_layer_sizes'    : []
        + [n_neurons for n_neurons in itertools.product([20, 60, 100], repeat=1)]
        + [n_neurons for n_neurons in itertools.product([20, 60, 100], repeat=2)]
        + [n_neurons for n_neurons in itertools.product([20, 60, 100], repeat=3)],
        # + [n_neurons for n_neurons in itertools.product([20, 60, 100], repeat=4)],
        # 'max_iter'              : [10000],#stats.randint(200,10000),
        # 'batch_size'            : [32],
        # 'solver'                : ['adam'], #'lbfgs'],
        'tol'                   : stats.loguniform(1e-7, 1e-1),
    },
    # { # DecisionTree 7
    #     #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
    #     #'DT__criterion'              : ['gini', 'entropy'],
    #     'splitter'               : ['best', 'random'],
    #     'max_depth'              : stats.randint(5,20), #maxima profundidade da arvore
    #     'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
    #     'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
    #     'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
    #     'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
    #     #'expansor'                    : [None, PolynomialFeatures(degree=2)],
    #     #'nX'                          : stats.randint(2,10),
    #     #'ny'                          : stats.randint(2,10),
    # },
    { # RandomForest 8
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    { # GradientBoosting 9
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'loss'                   : ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'learning_rate'          : stats.loguniform(1e-5, 1e1),
        'criterion'              : ['friedman_mse', 'squared_error'],
        'subsample'              : stats.uniform(),
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    # { # ExtraTrees 10
    #     #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
    #     'n_estimators'           : stats.randint(5,100), #Numero de arvores
    #     'criterion'              : ['squared_error', 'absolute_error'],
    #     #'RF__criterion'              : ['gini', 'entropy'],
    #     'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
    #     'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
    #     'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
    #     'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
    #     #'expansor'                    : [None, PolynomialFeatures(degree=2)],
    #     #'nX'                          : stats.randint(2,10),
    #     #'ny'                          : stats.randint(2,10),
    # },
    { # AdaBoostRegressor 11
        'n_estimators'              : stats.randint(5,100), #Numero de arvores
        'learning_rate'             : stats.loguniform(1e-3, 10),
        'loss'                      : ['linear', 'square', 'exponential'],
    },
    # { # BaggingRegressor 12
    #     'n_estimators'              : stats.randint(5,100), #Numero de arvores
    #     'max_samples'               : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
    #     'max_features'              : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
    #     'bootstrap'                 : [True, False],      #maxima quantidade de features para embasar a decisao de divisao
    # },
    # { # LightGBM 13
    #     'num_leaves'                : stats.randint(5,100), # max num folhas dos base learners
    #     'n_estimators'              : stats.randint(10,200), #Numero de arvores
    #     'learning_rate'             : stats.loguniform(1e-3, 1),
    #     # 'max_depth'                 : stats.randint(1,20), #maxima profundidade da arvore
    # },
    { # XGBoost 14
        'n_estimators'           : stats.randint(2,100), #Numero de arvores
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'learning_rate'          : stats.loguniform(1e-3, 1),
    },
]
# parameters

# %%
kfolds = 5
niters = 10
rkf = RepeatedKFold(n_splits=kfolds, n_repeats=niters, random_state=rs)
rkf
# Out:
# RepeatedKFold(n_repeats=10, n_splits=5, random_state=48)

# %% [markdown]
# #### Random Search

# %%
n_iter = 100 #Numero de iterações do rdmsearch
models=[]
for model, params in zip(models_ml, parameters):
    rdmsearch = RandomizedSearchCV(model[2], verbose=0, scoring='r2',
                                   param_distributions=params, n_iter=n_iter, n_jobs=6,
                                   cv=rkf, random_state=rs)

    models.append(
        # (model[0], model[1], rdmsearch)
        (model[1], model[2], rdmsearch, model[0])
    )

# models

# %%
def my_metrics(X_tr, X_te, y_tr, y_te, model1, model2=None):
    if model2 is None:
        y_hat_tr = model1.predict(X_tr)
        y_hat_te = model1.predict(X_te)
        r2_tr  = r2_score(y_tr, y_hat_tr)
        r2_te  = r2_score(y_te, y_hat_te)
        mae_tr = mean_absolute_error(y_tr, y_hat_tr)
        mae_te = mean_absolute_error(y_te, y_hat_te)
    else:
        y_hat_tr_trend = model1.predict(X_tr.trend)
        y_hat_te_trend = model1.predict(X_te.trend)
        y_hat_tr_resid = model2.predict(X_tr.seasonal+X_tr.resid)
        y_hat_te_resid = model2.predict(X_te.seasonal+X_te.resid)
        r2_tr  = r2_score(y_tr, y_hat_tr_trend + y_hat_tr_resid)
        r2_te  = r2_score(y_te, y_hat_te_trend + y_hat_te_resid)
        mae_tr  = mean_absolute_error(y_tr, y_hat_tr_trend + y_hat_tr_resid)
        mae_te  = mean_absolute_error(y_te, y_hat_te_trend + y_hat_te_resid)
    return r2_tr,r2_te,mae_tr,mae_te

# %% [markdown]
# #### Looping de Treinamento

# %%
res_dict = {
    'MODEL':[],
    'R2_TR':[],
    'R2_TE':[],
    'MAE_TR':[],
    'MAE_TE':[],
    'MODEL_OBJ':[],
}

models_copy = deepcopy(models)

for model_base in models:
    model_base_name, _ , model_base_instance, model_base_class = model_base
    print(f'Model Base:{model_base_name}', end=', ')
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        model_base_instance.fit(X=X_tr, y=y_tr);

    r2_tr,r2_te,mae_tr,mae_te = my_metrics(X_tr, X_te, y_tr, y_te, model_base_instance)

    res_dict['MODEL'].append(model_base_name)
    res_dict['R2_TR'].append(r2_tr)
    res_dict['R2_TE'].append(r2_te)
    res_dict['MAE_TR'].append(mae_tr)
    res_dict['MAE_TE'].append(mae_te)
    res_dict['MODEL_OBJ'].append(deepcopy(model_base_instance))
    print(f'R2={r2_te:.2f}')

    model_base_instance.fit(X=X_tr_dec.trend, y=y_tr_dec.trend);
    for model_resid in models_copy:
        model_resid_name, _ , model_resid_instance, _ = model_resid
        print(f'\t+Resid:{model_resid_name}', end=', ')

        model_resid_instance.fit(X=X_tr_dec.seasonal+X_tr_dec.resid, y=y_tr_dec.seasonal+y_tr_dec.resid);

        r2_tr,r2_te,mae_tr,mae_te = my_metrics(X_tr_dec, X_te_dec, y_tr, y_te, model_base_instance, model_resid_instance)
        res_dict['MODEL'].append(f'{model_base_name}.{model_resid_name}')
        res_dict['R2_TR'].append(r2_tr)
        res_dict['R2_TE'].append(r2_te)
        res_dict['MAE_TR'].append(mae_tr)
        res_dict['MAE_TE'].append(mae_te)
        res_dict['MODEL_OBJ'].append((deepcopy(model_base_instance),deepcopy(model_resid_instance)))
        print(f'R2={r2_te:.2f}')
# Out:
# Model Base:LinReg, R2=0.74
# 	+Resid:LinReg, R2=0.77
# 	+Resid:PolyReg, R2=0.77
# 	+Resid:SVM, R2=0.77
# 	+Resid:MLP, R2=0.78
# 	+Resid:RandomForest, R2=0.77
# 	+Resid:GradientBoosting, R2=0.76
# 	+Resid:AdaBoostRegressor, R2=0.79
# 	+Resid:XGBoost, R2=0.78
# Model Base:PolyReg, R2=0.83
# 	+Resid:LinReg, R2=0.80
# 	+Resid:PolyReg, R2=0.80
# 	+Resid:SVM, R2=0.79
# 	+Resid:MLP, R2=0.81
# 	+Resid:RandomForest, R2=0.80
# 	+Resid:GradientBoosting, R2=0.79
# 	+Resid:AdaBoostRegressor, R2=0.80
# 	+Resid:XGBoost, R2=0.81
# Model Base:SVM, R2=0.80
# 	+Resid:LinReg, R2=0.83
# 	+Resid:PolyReg, R2=0.83
# 	+Resid:SVM, R2=0.83
# 	+Resid:MLP, R2=0.83
# 	+Resid:RandomForest, R2=0.83
# 	+Resid:GradientBoosting, R2=0.82
# 	+Resid:AdaBoostRegressor, R2=0.83
# 	+Resid:XGBoost, R2=0.83
# Model Base:MLP, R2=0.81
# 	+Resid:LinReg, R2=0.85
# 	+Resid:PolyReg, R2=0.84
# 	+Resid:SVM, R2=0.84
# 	+Resid:MLP, R2=0.85
# 	+Resid:RandomForest, R2=0.84
# 	+Resid:GradientBoosting, R2=0.84
# 	+Resid:AdaBoostRegressor, R2=0.85
# 	+Resid:XGBoost, R2=0.85
# Model Base:RandomForest, R2=0.74
# 	+Resid:LinReg, R2=0.72
# 	+Resid:PolyReg, R2=0.71
# 	+Resid:SVM, R2=0.70
# 	+Resid:MLP, R2=0.73
# 	+Resid:RandomForest, R2=0.71
# 	+Resid:GradientBoosting, R2=0.71
# 	+Resid:AdaBoostRegressor, R2=0.72
# 	+Resid:XGBoost, R2=0.73
# Model Base:GradientBoosting, R2=0.76
# 	+Resid:LinReg, R2=0.71
# 	+Resid:PolyReg, R2=0.71
# 	+Resid:SVM, R2=0.70
# 	+Resid:MLP, R2=0.72
# 	+Resid:RandomForest, R2=0.71
# 	+Resid:GradientBoosting, R2=0.70
# 	+Resid:AdaBoostRegressor, R2=0.71
# 	+Resid:XGBoost, R2=0.72
# Model Base:AdaBoostRegressor, R2=0.64
# 	+Resid:LinReg, R2=0.59
# 	+Resid:PolyReg, R2=0.58
# 	+Resid:SVM, R2=0.54
# 	+Resid:MLP, R2=0.61
# 	+Resid:RandomForest, R2=0.57
# 	+Resid:GradientBoosting, R2=0.57
# 	+Resid:AdaBoostRegressor, R2=0.57
# 	+Resid:XGBoost, R2=0.59
# Model Base:XGBoost, R2=0.78
# 	+Resid:LinReg, R2=0.78
# 	+Resid:PolyReg, R2=0.78
# 	+Resid:SVM, R2=0.77
# 	+Resid:MLP, R2=0.79
# 	+Resid:RandomForest, R2=0.78
# 	+Resid:GradientBoosting, R2=0.77
# 	+Resid:AdaBoostRegressor, R2=0.78
# 	+Resid:XGBoost, R2=0.79

# %%
df_results = pd.DataFrame(res_dict)
df_results = df_results.sort_values('R2_TE', ascending=False).reset_index(drop=True)
df_results['IN'] = '.'.join(inputs)
df_results['OUT'] = output[0]
df_results.head(20)
# Out:
#                     MODEL     R2_TR     R2_TE    MAE_TR    MAE_TE  \
# 0             MLP.XGBoost  0.959644  0.850101  0.026870  0.041380
# 1                 MLP.MLP  0.924926  0.849657  0.036088  0.039890
# 2              MLP.LinReg  0.926596  0.846713  0.035766  0.041005
# 3   MLP.AdaBoostRegressor  0.938606  0.845082  0.035235  0.041436
# 4             MLP.PolyReg  0.929074  0.844309  0.035311  0.041946
# 5                 MLP.SVM  0.923000  0.843502  0.037615  0.043712
# 6        MLP.RandomForest  0.968292  0.841304  0.023522  0.042616
# 7    MLP.GradientBoosting  0.979235  0.837190  0.018503  0.043326
# 8                 PolyReg  0.909091  0.833406  0.040203  0.041501
# 9             SVM.XGBoost  0.896715  0.833278  0.047633  0.044333
# 10                SVM.SVM  0.858802  0.832227  0.054533  0.044029
# 11  SVM.AdaBoostRegressor  0.877497  0.831538  0.051469  0.044067
# 12                SVM.MLP  0.857009  0.830800  0.054602  0.041650
# 13             SVM.LinReg  0.860381  0.830157  0.054063  0.042418
# 14            SVM.PolyReg  0.860700  0.829528  0.054215  0.043287
# 15       SVM.RandomForest  0.907110  0.825684  0.045503  0.044682
# 16   SVM.GradientBoosting  0.919934  0.820862  0.042853  0.044948
# 17        PolyReg.XGBoost  0.953116  0.806559  0.029137  0.049379
# 18                    MLP  0.925120  0.806355  0.037546  0.049087
# 19            PolyReg.MLP  0.918047  0.805134  0.037845  0.047079
#
#                                             MODEL_OBJ  \
# 0   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 1   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 2   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 3   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 4   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 5   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 6   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 7   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 8   RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 9   (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 10  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 11  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 12  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 13  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 14  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 15  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 16  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 17  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 18  RandomizedSearchCV(cv=RepeatedKFold(n_repeats=...
# 19  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
#
#                           IN   OUT
# 0   DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 1   DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 2   DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 3   DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 4   DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 5   DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 6   DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 7   DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 8   DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 9   DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 10  DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 11  DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 12  DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 13  DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 14  DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 15  DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 16  DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 17  DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 18  DT.GR.NPHI.SW.RACEHM_LOG  RHOB
# 19  DT.GR.NPHI.SW.RACEHM_LOG  RHOB

# %%
lim = (0.5, 1)
fsize = (6, 6)

plt.figure(figsize=fsize)
sns.scatterplot(data=df_results.iloc[[0,8],:], y='R2_TE', x='R2_TR', hue='MODEL', s=100, palette='tab10')
plt.plot([0,1],[0,1], 'r--')
plt.xlim(lim)
plt.ylim(lim)
# Out:
# (0.5, 1.0)

# %%
best_model_index = 0
best_base_model_index = 8

best_model = df_results.loc[best_model_index,:]
best_base_model = df_results.loc[best_base_model_index,:]

y_hat = best_model['MODEL_OBJ'][0].predict(X_te_dec.trend) + best_model['MODEL_OBJ'][1].predict(X_te_dec.seasonal+X_te_dec.resid)
y_hat_base = best_base_model['MODEL_OBJ'].predict(X_te)

# %%
plt.figure(figsize=(6,9))
plt.plot(y_te,test_df['MD'], 'o', color='#999999', label='$y$ - observed');
plt.plot(y_hat_base,test_df['MD'], 'r', lw=2, label='$\hat{y}$ ('+f'$R^2$={r2_score(y_te, y_hat_base):.2f})')
plt.plot(y_hat,test_df['MD'], 'k', lw=2, label='$\hat{y}$ ('+f'$R^2$={r2_score(y_te, y_hat):.2f})')
plt.gca().invert_yaxis()
# plt.title(f'{best_model['MODEL']} prediction for {output[0]}, $R^2$:{r2_score(y_te, y_hat):.3f}')
plt.xlabel(f'Normalized {output[0]}')
plt.legend()
plt.ylabel('Depth[m]')
plt.grid()
pass;

# %%
fig = plt.figure(figsize=(5,5))
# fig = plt.figure(figsize=(12,12))
lim =(0,1)

sns.scatterplot(x=y_te.ravel(), y=y_hat.ravel(), s=50, color='.3')
# sns.kdeplot(x=y_te.ravel(), y=y_hat.ravel(), levels=10, linewidths=1, thresh=0.01, color='grey')

plt.plot(lim, lim, 'r--', label='$\hat{y}=y$')
plt.xlim(lim)
plt.ylim(lim)

plt.xlabel('$y$ - observed')
plt.ylabel('$\hat{y}$ - predictions')

plt.legend(loc='upper left')

plt.title(f"Observed x Predictions \n {df_results.loc[0,'MODEL']}: R²:{df_results.loc[0,'R2_TE']:.3f}")

# p = os.path.join(os.getcwd(), 'outputs', 'images_ensembles', '7_crossplot_y_yhat.eps')
# fig.savefig(p, format='eps')
pass;

# %%
prefix = 'ENS_RHOB_FILT'
binary = os.path.join(os.getcwd(), 'Outputs', f'{prefix}.pkl')
print(binary)

with open(binary, 'wb') as bin_file:
    pickle.dump(df_results, bin_file)
# Out:
# c:\Users\bewm\2_Projetos\Mestrado\SYSID_well_logs\Outputs\ENS_RHOB_FILT.pkl

# %% [markdown]
# #### Estudos dos parametros e tempos de treinamento

# %%
for i,m in enumerate(df_results['MODEL_OBJ']):
    if type(m)==tuple:
        tt = np.mean(m[0].cv_results_['mean_fit_time'])+np.mean(m[1].cv_results_['mean_fit_time'])
        name = m[0].best_estimator_.__class__.__name__ +'/'+ m[1].best_estimator_.__class__.__name__
        dfp1 = m[0].best_estimator_.get_params()
        dfp2 = m[1].best_estimator_.get_params()
        print (f"{name}:", f"{tt*1000:.0f} ms\n", dfp1,'\n', dfp2)
    else:
        tt = np.mean(m.cv_results_['mean_fit_time'])
        name = m.best_estimator_.__class__.__name__
        dfp1 = m.best_estimator_.get_params()
        print (f"{name}:", f"{tt*1000:.0f} ms\n", dfp1)
# Out:
# MLPRegressor/XGBRegressor: 1142 ms
#  {'activation': 'relu', 'alpha': 1.0948756437373352e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 60, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0016323623437366178, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.1809795132240306e-07, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.13149387720039063, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 40, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# MLPRegressor/MLPRegressor: 1333 ms
#  {'activation': 'relu', 'alpha': 1.0948756437373352e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 60, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0016323623437366178, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.1809795132240306e-07, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#  {'activation': 'tanh', 'alpha': 0.0004871011337999498, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 60, 20), 'learning_rate': 'constant', 'learning_rate_init': 0.002596088595636872, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.347982907478634e-06, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# MLPRegressor/LinearRegression: 737 ms
#  {'activation': 'relu', 'alpha': 1.0948756437373352e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 60, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0016323623437366178, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.1809795132240306e-07, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# MLPRegressor/AdaBoostRegressor: 971 ms
#  {'activation': 'relu', 'alpha': 1.0948756437373352e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 60, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0016323623437366178, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.1809795132240306e-07, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#  {'estimator': None, 'learning_rate': 2.87634878147148, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
# MLPRegressor/Pipeline: 739 ms
#  {'activation': 'relu', 'alpha': 1.0948756437373352e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 60, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0016323623437366178, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.1809795132240306e-07, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
# MLPRegressor/SVR: 746 ms
#  {'activation': 'relu', 'alpha': 1.0948756437373352e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 60, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0016323623437366178, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.1809795132240306e-07, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#  {'C': 388.83132860325986, 'cache_size': 200, 'coef0': 0.0, 'degree': 5, 'epsilon': 0.1, 'gamma': 0.016068216171270813, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# MLPRegressor/RandomForestRegressor: 907 ms
#  {'activation': 'relu', 'alpha': 1.0948756437373352e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 60, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0016323623437366178, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.1809795132240306e-07, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# MLPRegressor/GradientBoostingRegressor: 1128 ms
#  {'activation': 'relu', 'alpha': 1.0948756437373352e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 60, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.0016323623437366178, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.1809795132240306e-07, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# Pipeline: 3 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
# SVR/XGBRegressor: 414 ms
#  {'C': 746.6066437706427, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.07631733038879407, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.13149387720039063, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 40, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# SVR/SVR: 27 ms
#  {'C': 746.6066437706427, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.07631733038879407, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'C': 388.83132860325986, 'cache_size': 200, 'coef0': 0.0, 'degree': 5, 'epsilon': 0.1, 'gamma': 0.016068216171270813, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# SVR/AdaBoostRegressor: 243 ms
#  {'C': 746.6066437706427, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.07631733038879407, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'estimator': None, 'learning_rate': 2.87634878147148, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
# SVR/MLPRegressor: 573 ms
#  {'C': 746.6066437706427, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.07631733038879407, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'activation': 'tanh', 'alpha': 0.0004871011337999498, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 60, 20), 'learning_rate': 'constant', 'learning_rate_init': 0.002596088595636872, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.347982907478634e-06, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# SVR/LinearRegression: 18 ms
#  {'C': 746.6066437706427, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.07631733038879407, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# SVR/Pipeline: 20 ms
#  {'C': 746.6066437706427, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.07631733038879407, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
# SVR/RandomForestRegressor: 199 ms
#  {'C': 746.6066437706427, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.07631733038879407, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# SVR/GradientBoostingRegressor: 389 ms
#  {'C': 746.6066437706427, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.07631733038879407, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# Pipeline/XGBRegressor: 400 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.13149387720039063, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 40, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# MLPRegressor: 648 ms
#  {'activation': 'relu', 'alpha': 0.0003972359375049376, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 60, 60), 'learning_rate': 'constant', 'learning_rate_init': 0.0007790278991028049, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.598689760180514e-07, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# Pipeline/MLPRegressor: 563 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'activation': 'tanh', 'alpha': 0.0004871011337999498, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 60, 20), 'learning_rate': 'constant', 'learning_rate_init': 0.002596088595636872, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.347982907478634e-06, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# Pipeline/LinearRegression: 4 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# Pipeline/AdaBoostRegressor: 229 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'estimator': None, 'learning_rate': 2.87634878147148, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
# SVR: 16 ms
#  {'C': 106.18678644493198, 'cache_size': 200, 'coef0': 0.0, 'degree': 4, 'epsilon': 0.1, 'gamma': 0.14349150518834233, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# Pipeline/Pipeline: 5 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
# Pipeline/RandomForestRegressor: 168 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# XGBRegressor/MLPRegressor: 817 ms
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.23780709873089767, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 6, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 57, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#  {'activation': 'tanh', 'alpha': 0.0004871011337999498, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 60, 20), 'learning_rate': 'constant', 'learning_rate_init': 0.002596088595636872, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.347982907478634e-06, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# Pipeline/SVR: 13 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'C': 388.83132860325986, 'cache_size': 200, 'coef0': 0.0, 'degree': 5, 'epsilon': 0.1, 'gamma': 0.016068216171270813, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# Pipeline/GradientBoostingRegressor: 384 ms
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# XGBRegressor/XGBRegressor: 596 ms
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.23780709873089767, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 6, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 57, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.13149387720039063, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 40, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# LinearRegression/AdaBoostRegressor: 218 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'estimator': None, 'learning_rate': 2.87634878147148, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
# XGBRegressor/LinearRegression: 230 ms
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.23780709873089767, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 6, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 57, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# XGBRegressor/Pipeline: 233 ms
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.23780709873089767, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 6, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 57, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
# XGBRegressor/AdaBoostRegressor: 450 ms
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.23780709873089767, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 6, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 57, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#  {'estimator': None, 'learning_rate': 2.87634878147148, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
# XGBRegressor/RandomForestRegressor: 398 ms
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.23780709873089767, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 6, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 57, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# XGBRegressor: 363 ms
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.1316696975806964, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 91, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# LinearRegression/MLPRegressor: 574 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'activation': 'tanh', 'alpha': 0.0004871011337999498, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 60, 20), 'learning_rate': 'constant', 'learning_rate_init': 0.002596088595636872, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.347982907478634e-06, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# LinearRegression/XGBRegressor: 392 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.13149387720039063, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 40, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# LinearRegression/LinearRegression: 3 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# LinearRegression/SVR: 11 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'C': 388.83132860325986, 'cache_size': 200, 'coef0': 0.0, 'degree': 5, 'epsilon': 0.1, 'gamma': 0.016068216171270813, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# XGBRegressor/GradientBoostingRegressor: 557 ms
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.23780709873089767, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 6, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 57, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# LinearRegression/Pipeline: 5 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
# XGBRegressor/SVR: 239 ms
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.23780709873089767, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 6, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 57, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#  {'C': 388.83132860325986, 'cache_size': 200, 'coef0': 0.0, 'degree': 5, 'epsilon': 0.1, 'gamma': 0.016068216171270813, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# LinearRegression/RandomForestRegressor: 184 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# GradientBoostingRegressor: 340 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# LinearRegression/GradientBoostingRegressor: 374 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# LinearRegression: 2 ms
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# RandomForestRegressor: 173 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# RandomForestRegressor/MLPRegressor: 713 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 14, 'max_features': 0.9184743424662997, 'max_leaf_nodes': 102, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 70, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'activation': 'tanh', 'alpha': 0.0004871011337999498, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 60, 20), 'learning_rate': 'constant', 'learning_rate_init': 0.002596088595636872, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.347982907478634e-06, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# RandomForestRegressor/XGBRegressor: 563 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 14, 'max_features': 0.9184743424662997, 'max_leaf_nodes': 102, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 70, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.13149387720039063, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 40, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# GradientBoostingRegressor/MLPRegressor: 851 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
#  {'activation': 'tanh', 'alpha': 0.0004871011337999498, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 60, 20), 'learning_rate': 'constant', 'learning_rate_init': 0.002596088595636872, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.347982907478634e-06, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# GradientBoostingRegressor/XGBRegressor: 746 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.13149387720039063, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 40, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# RandomForestRegressor/LinearRegression: 168 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 14, 'max_features': 0.9184743424662997, 'max_leaf_nodes': 102, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 70, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# RandomForestRegressor/AdaBoostRegressor: 408 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 14, 'max_features': 0.9184743424662997, 'max_leaf_nodes': 102, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 70, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'estimator': None, 'learning_rate': 2.87634878147148, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
# RandomForestRegressor/Pipeline: 171 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 14, 'max_features': 0.9184743424662997, 'max_leaf_nodes': 102, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 70, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
# GradientBoostingRegressor/AdaBoostRegressor: 536 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
#  {'estimator': None, 'learning_rate': 2.87634878147148, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
# GradientBoostingRegressor/LinearRegression: 313 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# RandomForestRegressor/RandomForestRegressor: 334 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 14, 'max_features': 0.9184743424662997, 'max_leaf_nodes': 102, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 70, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# GradientBoostingRegressor/RandomForestRegressor: 490 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# GradientBoostingRegressor/Pipeline: 314 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
# RandomForestRegressor/GradientBoostingRegressor: 539 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 14, 'max_features': 0.9184743424662997, 'max_leaf_nodes': 102, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 70, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# GradientBoostingRegressor/GradientBoostingRegressor: 648 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# RandomForestRegressor/SVR: 178 ms
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 14, 'max_features': 0.9184743424662997, 'max_leaf_nodes': 102, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 70, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
#  {'C': 388.83132860325986, 'cache_size': 200, 'coef0': 0.0, 'degree': 5, 'epsilon': 0.1, 'gamma': 0.016068216171270813, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# GradientBoostingRegressor/SVR: 322 ms
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
#  {'C': 388.83132860325986, 'cache_size': 200, 'coef0': 0.0, 'degree': 5, 'epsilon': 0.1, 'gamma': 0.016068216171270813, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# AdaBoostRegressor: 222 ms
#  {'estimator': None, 'learning_rate': 2.87634878147148, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
# AdaBoostRegressor/MLPRegressor: 746 ms
#  {'estimator': None, 'learning_rate': 0.9911177144468986, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
#  {'activation': 'tanh', 'alpha': 0.0004871011337999498, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (60, 60, 20), 'learning_rate': 'constant', 'learning_rate_init': 0.002596088595636872, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 48, 'shuffle': True, 'solver': 'adam', 'tol': 1.347982907478634e-06, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# AdaBoostRegressor/XGBRegressor: 641 ms
#  {'estimator': None, 'learning_rate': 0.9911177144468986, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
#  {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.13149387720039063, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 40, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
# AdaBoostRegressor/LinearRegression: 229 ms
#  {'estimator': None, 'learning_rate': 0.9911177144468986, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# AdaBoostRegressor/Pipeline: 231 ms
#  {'estimator': None, 'learning_rate': 0.9911177144468986, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
#  {'memory': None, 'steps': [('Poly', PolynomialFeatures()), ('Reg', LinearRegression())], 'verbose': False, 'Poly': PolynomialFeatures(), 'Reg': LinearRegression(), 'Poly__degree': 2, 'Poly__include_bias': True, 'Poly__interaction_only': False, 'Poly__order': 'C', 'Reg__copy_X': True, 'Reg__fit_intercept': True, 'Reg__n_jobs': None, 'Reg__positive': False}
# AdaBoostRegressor/AdaBoostRegressor: 458 ms
#  {'estimator': None, 'learning_rate': 0.9911177144468986, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
#  {'estimator': None, 'learning_rate': 2.87634878147148, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
# AdaBoostRegressor/RandomForestRegressor: 399 ms
#  {'estimator': None, 'learning_rate': 0.9911177144468986, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
#  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 11, 'max_features': 0.679914691937932, 'max_leaf_nodes': 132, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 84, 'n_jobs': None, 'oob_score': False, 'random_state': 48, 'verbose': 0, 'warm_start': False}
# AdaBoostRegressor/GradientBoostingRegressor: 571 ms
#  {'estimator': None, 'learning_rate': 0.9911177144468986, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
#  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.04361048369177966, 'loss': 'huber', 'max_depth': 18, 'max_features': 0.8140551285547241, 'max_leaf_nodes': 52, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 96, 'n_iter_no_change': None, 'random_state': 48, 'subsample': 0.6451517499639254, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}
# AdaBoostRegressor/SVR: 239 ms
#  {'estimator': None, 'learning_rate': 0.9911177144468986, 'loss': 'exponential', 'n_estimators': 91, 'random_state': 48}
#  {'C': 388.83132860325986, 'cache_size': 200, 'coef0': 0.0, 'degree': 5, 'epsilon': 0.1, 'gamma': 0.016068216171270813, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}

# %% [markdown]
# add rmse

# %%
# prefix = 'DECOMP_RHOB_FILT'
from sklearn.metrics import mean_squared_error
# df_results = pd.read_pickle(f'./Outputs/{prefix}.pkl')

def calc_rmse_te(row):
    m = row['MODEL_OBJ']
    if type(m) == tuple:
        y_hat_te_trend = m[0].predict(X_te_dec.trend)
        y_hat_te_resid = m[1].predict(X_te_dec.seasonal+X_te_dec.resid)
        rmse_te  = mean_squared_error(y_te, y_hat_te_trend + y_hat_te_resid)**0.5
    else:
        y_hat_te = m.predict(X_te)
        rmse_te = mean_squared_error(y_te, y_hat_te)**0.5
    return rmse_te

def calc_rmse_tr(row):
    m = row['MODEL_OBJ']
    if type(m) == tuple:
        y_hat_tr_trend = m[0].predict(X_tr_dec.trend)
        y_hat_tr_resid = m[1].predict(X_tr_dec.seasonal+X_tr_dec.resid)
        rmse_tr  = mean_squared_error(y_tr, y_hat_tr_trend + y_hat_tr_resid)**0.5
    else:
        y_hat_tr = m.predict(X_tr)
        rmse_tr = mean_squared_error(y_tr, y_hat_tr)**0.5
    return rmse_tr

df_results['RMSE_TR'] = df_results.apply(calc_rmse_tr, axis=1)
df_results['RMSE_TE'] = df_results.apply(calc_rmse_te, axis=1)

binary = os.path.join(os.getcwd(), 'Outputs', f'{prefix}.pkl')

with open(binary, 'wb') as bin_file:
    pickle.dump(df_results, bin_file)

df_results
# Out:
#                                   MODEL     R2_TR     R2_TE    MAE_TR  \
# 0                           MLP.XGBoost  0.959644  0.850101  0.026870
# 1                               MLP.MLP  0.924926  0.849657  0.036088
# 2                            MLP.LinReg  0.926596  0.846713  0.035766
# 3                 MLP.AdaBoostRegressor  0.938606  0.845082  0.035235
# 4                           MLP.PolyReg  0.929074  0.844309  0.035311
# ..                                  ...       ...       ...       ...
# 67            AdaBoostRegressor.PolyReg  0.879804  0.580160  0.051118
# 68  AdaBoostRegressor.AdaBoostRegressor  0.889110  0.573984  0.050393
# 69       AdaBoostRegressor.RandomForest  0.923429  0.570652  0.041502
# 70   AdaBoostRegressor.GradientBoosting  0.935104  0.566392  0.037986
# 71                AdaBoostRegressor.SVM  0.870535  0.544720  0.053717
#
#       MAE_TE                                          MODEL_OBJ  \
# 0   0.041380  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 1   0.039890  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 2   0.041005  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 3   0.041436  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 4   0.041946  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# ..       ...                                                ...
# 67  0.082696  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 68  0.084049  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 69  0.084476  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 70  0.084370  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
# 71  0.088366  (RandomizedSearchCV(cv=RepeatedKFold(n_repeats...
#
#                           IN   OUT   RMSE_TR   RMSE_TE
# 0   DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.036095  0.057352
# 1   DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.049231  0.057437
# 2   DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.048681  0.057996
# 3   DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.044521  0.058304
# 4   DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.047852  0.058449
# ..                       ...   ...       ...       ...
# 67  DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.062294  0.095982
# 68  DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.059833  0.096685
# 69  DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.049720  0.097063
# 70  DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.045773  0.097543
# 71  DT.GR.NPHI.SW.RACEHM_LOG  RHOB  0.064651  0.099951
#
# [72 rows x 10 columns]
